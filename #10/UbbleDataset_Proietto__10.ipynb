# %% [markdown]
# # Face Recognition #10
#
# - We are using: Ubble dataset
#
# We have used during the computation of the FAR and TAR only the encodings that have been previously generated in order to speed up the execution.
# Each person is described by a vector that contains a certain number of  encodings generated from images among all the ones available for a certain person in a video.

# %% [markdown]
# ##Basic import

# %%
import sys
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/PRIM/'  # your new root path

sys.path.append(os.path.join(root_path, 'notebooks')) # for importing from utils.py

# !pip install face_recognition
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: face_recognition in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.3)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.2)

# %%
import argparse
import pickle
import cv2
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os
import dlib
import matplotlib.pyplot as plt
import time
import pdb
import numpy as np
import random
import csv

print(dlib.DLIB_USE_CUDA)
# Out:
# True

# %%
#os.listdir(root_path + 'face_videos/face_videos')

# %% [markdown]
# ## Creating new encodings & boxes

# %%
def createEncodings(dataset_vector, name , detection = 'cnn'):

    # grab the paths to the input images in our dataset
    print("[INFO] quantifying faces...")
    '''
    We're going to take all the images and create the encodings
    '''
    if len(dataset_vector )<= 0:
      print("AN ERROR OCCURRED FOR ",name)
      return

    images = dataset_vector#create the encodings for each frame in the video --> it will take a lot of time to do all the videos-> 5/6 hours

    # initialize the list of known encodings and known names
    knownEncodings = []
    knownNames = []

    ratios = []
    face_areas = []
    image_areas = []
        
    # loop over the image paths
    for image in images:
        # extract the person name from the image path
        #print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))

        # load the input image and convert it from RGB (OpenCV ordering)
        # to dlib ordering (RGB)
        rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # detect the (x, y)-coordinates of the bounding boxes
        # corresponding to each face in the input image
        boxes = face_recognition.face_locations(rgb,model=detection)

        ######################### FACE RESOLUTION LOGIC
        for face_location in boxes:
            try:
                top, right, bottom, left = face_location
            except IndexError:
                top = right = bottom = left = 0

            area_face = (bottom-top) * (right-left)
            area_image = image.shape[0] * image.shape[1]
            ratio = area_face/area_image * 100
            #print('face:', area_face, 'image:', area_image, 'ratio:', ratio)

            ratios.append(ratio)
            face_areas.append(area_face)
            image_areas.append(area_image)
        #########################

        # compute the facial embedding for the face
        encodings = face_recognition.face_encodings(rgb, boxes)

        # loop over the encodings
        for encoding in encodings:
            # add each encoding + name to our set of known names and
            # encodings
            knownEncodings.append(encoding)
            knownNames.append(name)
            
    # dump the facial encodings + names to disk
    print("[INFO] serializing encodings..." + name)
    data = {"encodings": knownEncodings, "names": knownNames}
    file_name = root_path + "/encodings_face_videos_half/" + name + '.pkl'
    
    print(len(knownEncodings))

    f = open(file_name, "wb")
    f.write(pickle.dumps(data))
    f.close()


    #-------------------------------------------------------------------#
    boxfile = open(root_path + "/boxes/box_" + name + ".pkl", "wb")
    boxdata = {"ratio": ratios, "face": face_areas, "image": image_areas}
    boxfile.write(pickle.dumps(boxdata))
    boxfile.close()

# %%
def readFrames(path):
  
  video = cv2.VideoCapture(path)
  frames = []
  while(1):
      ret, frame = video.read()
      if ret == True:
        frames.append(frame)
      else:
          break
  return frames

# %%
base_video_path = root_path + 'face_videos/face_videos/'

# %%
'''
#encoding already generated not need of this codde anymore
videos = os.listdir(base_video_path)
global_start = time.time()
count = 0
for video_name in videos:
  start = time.time()
  #frames = readFrames(base_video_path + video_name)#remove the comment if you neeed to train new encodings
  frames = frames[0:int(len(frames)/2)]
  #createEncodings(frames,video_name)
  end = time.time()
  print('Time_enc:', end-start)
  print(count)
  count += 1

global_end = time.time()
print('Total time:', global_end-global_start)
'''
# Out:
# "\n#encoding already generated not need of this codde anymore\nvideos = os.listdir(base_video_path)\nglobal_start = time.time()\ncount = 0\nfor video_name in videos:\n  start = time.time()\n  #frames = readFrames(base_video_path + video_name)#remove the comment if you neeed to train new encodings\n  frames = frames[0:int(len(frames)/2)]\n  #createEncodings(frames,video_name)\n  end = time.time()\n  print('Time_enc:', end-start)\n  print(count)\n  count += 1\n\nglobal_end = time.time()\nprint('Total time:', global_end-global_start)\n"

# %% [markdown]
# ## Code for test

# %%
def faceRecognitionENC(encodings_1, encodings_2, ratio, detection='cnn', show=False, tolerance = 0.6, min_area = 1):
    '''
    New version it only works with already made encodings
    encodings_1: single encoding of the person we want to recognize
    encodings_2: encodings of the person of which we know the name
    '''
    start = time.time()


    data = encodings_2

    dist = 1.0
    # initialize the list of names for each face detected
    names = []
    ######################### FACE RESOLUTION LOGIC
    discarded = "discarded"
    
    if (ratio < min_area):
        #discard the picture
        #print('dicard')
        return discarded, dist
    #########################
    
    # attempt to match each encoding to our known encodings
    if global_number_enc > 0:
      data = data["encodings"][0:global_number_enc]
    else:
      data = data["encodings"]
    
    matches = face_recognition.compare_faces(data,encodings_1, tolerance= tolerance)
    
    name = "unknown"

    # check to see if we have found a match
    if True in matches:
      # Use the known face with the smallest distance to the new face 
      #this can help if in the video to recognize there is more than one person
      face_distances = face_recognition.face_distance(data, encodings_1)
      best_match_index = np.argmin(face_distances)

      if matches[best_match_index]:
          name = encodings_2["names"][best_match_index]
          dist = face_distances[best_match_index]

    # update the list of names
    try:
        name = name.split('/')[2]
    except:
        name = name
    names.append(name)
    
    return names, dist
    
def encodingsRead(path):
    ## PAY ATTENTION:: You need to create the encoding for you dataset using encode_face.py
    data = pickle.loads(open(path, "rb").read())
    return data

def boxesRead(path):
    try:
        data = pickle.loads(open(path, "rb").read())
    except FileNotFoundError:
        boxdata= np.ones(100)
        data = {"ratio": boxdata, "face": boxdata, "image": boxdata}
        print("---- Default box construction")
    return data

# %%
import json
#code to retrieve the real name starting from the rec name
with open( root_path +'labelled_videos.json') as json_file:
  data = json.load(json_file)

def readTrueName(rec_name):
  
  for real_name in data:
    if rec_name in data[real_name]:
      return real_name
  return "unknown"

# %% [markdown]
# Two types of early stopping:
# * we reject the acces (return False) if after $minFrames$ the percentage of times the algorithm returns False is greater than $0.5$
# * we grant the acces if the function **makeDecision** return true. This function starting from $minFrames/5$ compare the average distances (or the min) of the encodings till that moment and make a decison taking into account the number of frames alredy received.

# %%
def makeDecision(distances,threshold,n_frames,min_frames_to_compare, mod = 'avg'):
  


  if len(distances)>0:
      if  mod == 'avg':
        min_d = np.mean(distances)
      else:
        if mod == 'min':
          min_d = np.amin(distances)
        else:
          print('Only avg or min supperted the default will be used')
          min_d = np.mean(distances)

      dists = np.linspace(0.2, 0.5,50)
      frames = np.linspace(int(min_frames_to_compare/5), min_frames_to_compare,50)
      '''
      HAND-MADE VARIANT
      if min_d <= 0.2:
        return True
      if min_d <= 0.25 and len(distances)>=(2/3)*min_frames_to_compare:
        return True
      if min_d <= 0.3 and len(distances)>=(3/4)*min_frames_to_compare:
        return True
      if min_d <= 0.35 and len(distances)>=(4/5)*min_frames_to_compare:
        return True
      if min_d <= 0.40 and len(distances)>=(5/6)*min_frames_to_compare:
        return True   
      if min_d <= 0.45 and len(distances)>=(6/7)*min_frames_to_compare:
        return True
      if min_d <= 0.50 and len(distances)>=(7/8)*min_frames_to_compare:
        return True
      '''
      for i in range(0,len(dists)):
        if min_d <= dists[i] and len(distances) >= frames[i]:
          return True                    
      
  if len(distances)/n_frames > threshold:
    return True
  
  return False

# %%
def faceRecOnENC(encoding_path, encodings, correct_person,test_person, detection='cnn',min_threshold = 0.85, 
                    min_frames_to_compare = 30 ,
                    show=False, tolerance = 0.6,
                    mod = 'avg',
                    min_area = 1):
    
    encodings_to_compare = encodingsRead(encoding_path)
    encodings_to_compare = encodings_to_compare["encodings"]#encoding of a different person
    
    
    
    box_path = root_path +"boxes/box_" + test_person + ".pkl"
    #pdb.set_trace()
    
    boxes_to_compare = boxesRead(box_path)
    ratio_to_compare = boxes_to_compare['ratio']
    
    test_person = readTrueName(test_person)

    start = time.time()

    analysed_frames = 0
    correct_frames = 0
    negative_frames = 0
    neutrum_frames = 0
    ignored_frames = 0
    global total_ignored
    total_ignored = 0
 #-----------------------#
    distances = []


    # grab the paths to the input images in our dataset
    #print("[INFO] Recognizing faces...")
    #total_frames = len(encodings_to_compare)
    #print("[INFO] elements:", total_frames)

    #we had some cases where no faces where recognised
    if len(encodings_to_compare) <= 0:
        return False, 0, 0, 0, 0


    # loop over the encodings
    frame_count = 0
    min_area_max = np.max(ratio_to_compare) * ((-1) * min_area) / 100
    for enc in encodings_to_compare:
        # extract the person name from the image path
        #print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
    
      ratio = ratio_to_compare[frame_count]
      if( min_area < 0): 
        min_area = min_area_max

      person, dist= faceRecognitionENC(enc, encodings, ratio,  detection='cnn', show=show, tolerance = 0.55, min_area = min_area)
    
      analysed_frames += 1
      frame_count += 1 
      if( person == "discarded"):
        # we are ignoring the frame
        analysed_frames -= 1
        ignored_frames += 1 
        #print("Discarded frame", frame_count, "ratio:", ratio)
        continue
      
      person = readTrueName(person[0])
      
      if(person == correct_person):#recognised
        distances.append(dist)
        

        if (correct_person == test_person): #correctly recognised
          correct_frames+=1 #true positive
        
        else:#wrongly recognised
          negative_frames += 1 #false positive

      else:#not recognized
        neutrum_frames += 1

      correct_rate = correct_frames/analysed_frames
      neutrum_rate = neutrum_frames/analysed_frames
      negative_rate = negative_frames/analysed_frames
      total_ignored = total_ignored + ignored_frames


      #-----------------------------------------------------------------------------------------------------------------#

      #TODO--> IMPROVE WITH DISTANCE CHECK
      #early stopping for negative result
      if (analysed_frames >= min_frames_to_compare ): # ex 30fps --> 45 frames = 1.5 second  ---early stopping
          
          if neutrum_frames/analysed_frames > 0.5:#early stopping for the negative 
            return False,correct_rate, neutrum_rate, negative_rate, analysed_frames

      #early stopping for positive result
      if (analysed_frames >= min_frames_to_compare/5): # ex 30fps --> 15 frames = 0.5 second  ---early stopping
          
          if(makeDecision(distances,min_threshold,analysed_frames,min_frames_to_compare, mod = mod)):
            return True,correct_rate, neutrum_rate, negative_rate, analysed_frames
      
      #--------------------------------------------------------------------------------------------------------------------#

    #for end --> if we don't have so many frames
          
    if (correct_frames + negative_frames)/analysed_frames > min_threshold:#ex 85% of the frames are recognised
      return True,correct_rate, neutrum_rate, negative_rate, analysed_frames
    else:
      return False,correct_rate, neutrum_rate, negative_rate, analysed_frames

# %%
def removeFaces(curr_encoding,person,min_area):  
  #pdb.set_trace()
  box_path = root_path +"boxes/box_" + person 
  boxes_to_compare = boxesRead(box_path)
  ratio_to_compare =np.array(boxes_to_compare['ratio'])

  if len(ratio_to_compare)<=0:
    print(person)
  if( min_area < 0): 
    min_area_max = np.max(ratio_to_compare) * ((-1) * min_area) / 100
    min_area = min_area_max


  index = np.where(ratio_to_compare > min_area)[0]

  enc = np.array(curr_encoding['encodings'])
  names = np.array(curr_encoding['names'])
  #print('Before:',len(enc))
  enc = enc[index]
  #print('After:',len(enc))
  names = names[index]
  values = [enc,names]

  keys = ['encodings', 'names']
  dictionary = dict(zip(keys, values))
  
  return dictionary

# %%
p = 'rec-11ed9484-a061-4d69-b47e-2bed217eb329-nLhwAugvim-LrNOD5PRIWWh1xhr-1582131518521-video-face.webm.pkl'
box_path = root_path +"boxes/box_" + p 
boxes_to_compare = boxesRead(box_path)
ratio_to_compare =np.array(boxes_to_compare['ratio'])
#print(ratio_to_compare)
min_area_max = np.max(ratio_to_compare)
print(min_area_max)
# Out:
# 8.75173611111111

# %%
en = encodingsRead(root_path + "/encodings_face_videos_half/rec-620abe15-99a0-4b24-b864-764458b47141-Segl5M2EHf-HWssZtA93XUhcm6S-1582731724460-video-face.webm.pkl")
en = en['encodings']
print(len(en))
# Out:
# 0

# %% [markdown]
# The CrossedTest compare the encodings of one person with all the other encodings (same person or not)  in order to compute later Far and Tar.
# Here each person is compared with all the other except that with himself.

# %%
def performCrossedTestENC(min_v=0, max_v=1000, threshold=0.85, log=False, tolerance = 0.6, mod = 'avg', min_area =1):
    print("-------------------------")
    print("TEST STARTED")
    print("-------------------------")
    start = time.time()

    count = 0
    enc_list = os.listdir(encodings_folder)
    test_dir = os.listdir(test_path)

    log_folder_base = 'logs_' + str(tolerance) + '_'+str(threshold) +'_'+str(global_number_enc)+'_'+str(global_min_frames)+'_'+str(mod)+'/'

    count_p = 0
    for encoding in enc_list:
        count = count + 1
        if(count < min_v):
            continue
        if(count > max_v):
            break

        n_test = 0
        n_correct = 0
        
        enc_name = encoding[0:len(encoding)-4]#removing '.pkl' from name
        encoding_path = encodings_folder + encoding
        
        start_2 = time.time()
        curr_encoding = encodingsRead(encoding_path)
        

        real_name_curr_encoding = readTrueName(enc_name)
        
        #there are some people that don't have a label
        if (real_name_curr_encoding == "unknown" or real_name_curr_encoding =="documents" or len(curr_encoding['encodings'])<=0):
          continue

       #-------------------------------------------#
        
        curr_encoding = removeFaces(curr_encoding,encoding,min_area)
        #-----------------------------------------------#

        print('[ENC] Using encoding:', enc_name)
        count_p += 1
        if( log == True):
          #log_folder = log_folder_base + 'F/'
          try:
              os.mkdir(root_path + '/logs#10/' + log_folder_base)
              #os.mkdir(root_path + '/logs#10/' + log_folder)
          except FileExistsError:
              print('Already existing folder')

          logfile = open(root_path + '/logs#10/' + log_folder_base + "log_" + enc_name + ".txt", "w")

        
        for person in test_dir:
            
            if ( enc_name == person[0:len(person)-4]):#removing '.pkl' from name 
              continue

            test_enc = test_path + person            
            person = person[0:len(person)-4]
            
            #print('Testing on test encoding:', person)
            
            real_name_test_encoding = readTrueName(person)

            if (real_name_test_encoding == "unknown" or real_name_test_encoding =="documents"):
              continue
            
            #video = readFrames(base_video_path +  person)#we send also the video to simulate the real input data but we use the encodings previously generated in order to speed up the execution
            #pdb.set_trace()
            # test the encodings of testset               
            v, a, b, c, d = faceRecOnENC(test_enc, curr_encoding, real_name_curr_encoding, person, min_threshold=threshold, show=False, tolerance = tolerance, 
                                         min_frames_to_compare = global_min_frames,mod = mod, 
                                         min_area = min_area)
                                      
            
            if(log== True):
                line = person + " " + str(d) + " " + str(v) + " " + str(a) + " " + str(b) + " " + str(c) + "\n"
                logfile.write(line)
                #print(line)
            if( v == True):
                n_correct += 1

        if(log == True):
            logfile.close()
        
        end_2 = time.time()
        


        print("-------------------------")
        print('The comparison last:', end_2-start_2)
        print("-------------------------")
        if count %10 == 0:
          print('Percentage of people:', int(count_p*100/285),'%')
          print("-------------------------")
    
    end = time.time()
    print("-------------------------")
    print("TEST ENDED")
    print("-------------------------")
    print('This test last:', end-start)
    return

# %% [markdown]
# ## Code for Statistics

# %% [markdown]
# ###Pies

# %%
from sklearn.metrics import roc_curve, auc


from google.colab import files

def showStats(folder,tolerance, show = True):

  print("##############")
  print("TOLERANCE",tolerance)
  print("#############")


  FAR_path = folder

  files = os.listdir(FAR_path)


  values = [0.85]
  confirmed_rate = np.zeros(len(values))
  i = 0

  for thr in values:
      total_files = 0
      recognized = 0
      notdetected = 0
      wrong = 0
      wrong_confirmed = 0
      wrong_confirmed2 = 0
      wrong_confirmed3 = 0
      wrong_confirmed4 = 0

      global_pos_count = 0
      global_pos = 0
      global_neg_count = 0
      global_neg = 0

      ####
      n_frames = 0
      one_wrong_rec = 0
      persons = 0
      for f in files:
          if( f.startswith('log') == True):
              filev = open(FAR_path + f, "r")
              vector = f.split('_')[1].split(".")[0]
              correct_person = readTrueName(vector + '.webm')
              lines = filev.readlines()
              persons += 1
              for line in lines: 
                  
                  name = line.split(' ')[0]
                  total_files += 1

                  n_frames += int(line.split(' ')[1])
                  rec_flag = line.split(' ')[2]

                  #pdb.set_trace()
                  rec_percentage = float(line.split(' ')[3])
                  notdec_percentage = float(line.split(' ')[4])
                  notrec_percentage = float(line.split(' ')[5])

                  if(readTrueName(name) == correct_person):#same person
                      
                      if rec_flag == 'True':#acces granted correctly
                        global_pos +=1
                      
                      global_pos_count+=1
                  
                  else:#non sono la stessa persona
                      if rec_flag == 'True':#wrong acces granted 
                        global_neg +=1
                      
                      global_neg_count+=1



                  recognized = recognized + rec_percentage
                  notdetected = notdetected + notdec_percentage
                  wrong = wrong + notrec_percentage

                  if(notrec_percentage > thr):
                      wrong_confirmed = wrong_confirmed + 1
      
      if(total_files == 0):
          total_files = 1
      confirmed_rate[i] = wrong_confirmed / total_files
      wrong_confirmed = 0
      i = i +1

  ## equal for each iteration
  positive = recognized / total_files 
  undetected = notdetected / total_files
  negative = wrong / total_files

  wrong_rec_on_persons = one_wrong_rec / (persons-1)

  #----------------------------------------------------------------------------#
  
  ## WRONG ONES WHERE ASSIGNED TO THE PERSON EVEN IF HE WASN'T
  '''
  if show:
    labels = ['Correct', 'NotRecognized', 'Wrong']
    colors = ['Blue', 'Yellow', 'Orange']
    sizes1 = [positive, undetected, negative]


    plt.pie(sizes1, labels=labels, shadow=True, startangle=90, colors=colors)
    plt.title('Recognition average over all the images')
    plt.legend()
    plt.show()
    print('Percentage of overall images that were correctly not recognized:', undetected)
    print('\n\n')
  '''
  #--------------------------------------------------------------------------------------------#
  
  cfr = global_neg/global_neg_count
  
  if show:
    labels = ['Wrongly Confirmed', 'Correclty Not Confirmed']
    colors = ['Red','Green']
    sizes1 = [cfr, (1 - cfr)]



    plt.pie(sizes1, labels=labels, shadow=True, startangle=90, colors=colors)
    plt.title('Confirmation percentage using our algorithm metrics')
    plt.show()
    print('Percentage of TRR ' 'is', 1-cfr)
    print('Percentage of FAR ' 'is', cfr)
    print('\n\n')
  
  TRR = 1-cfr
  FAR = cfr
  #--------------------------------------------------------------------------------------------------------------------------#

  cfr = global_pos/global_pos_count
  if show:
    labels = ['Correctly Confirmed', 'Wrongly Not Confirmed']
    colors = ['Green', 'Red']
    sizes1 = [cfr, (1 - cfr)]


    plt.pie(sizes1, labels=labels, shadow=True, startangle=90, colors=colors)
    plt.title('Confirmation percentage using our algorithm metrics')
    plt.show()
    print('Percentage of TAR ' 'is', cfr)
    print('Percentage of FRR ' 'is', 1-cfr)

  TAR = cfr
  FRR = 1-cfr
  #--------------------------------------------------------------------------------------------------------------------------#
  #mean FRAMES

  print('Mean frames analysed',n_frames/(persons*persons))
  return TRR,FAR,TAR,FRR

# %% [markdown]
# ###ROC&stat

# %%
def showStatsROC(log_folder):
  files = os.listdir(log_folder)


  values = [0.20, 0.40, 0.45, 0.55, 0.60, 0.65, 0.75, 0.80, 0.85, 0.90, 0.95, 0.99, 0.9999]
  confirmed_rate = np.zeros(len(values))
  confirmed_rateT = np.zeros(len(values))
  i = 0

  for thr in values:
      total_files = 0    
      total_files_t = 0
      recognized = 0
      notdetected = 0
      wrong = 0
      confirmed = 0
      wrong_confirmed = 0
      wrong_confirmed2 = 0
      wrong_confirmed3 = 0
      wrong_confirmed4 = 0

      ####
      one_wrong_rec = 0
      persons = 0
      for f in files:
          if( f.startswith('log') == True):
              filev = open(log_folder + f, "r")
              vector = f.split('_')[1].split(".")[0]
              correct_person = readTrueName(vector + ".webm")
              lines = filev.readlines()
              persons += 1
              for line in lines: 
                  #we don't want to make statistics on the same person
                  name = line.split(' ')[0]

                  rec_flag = line.split(' ')[2]
                  rec_percentage = float(line.split(' ')[3])
                  notdec_percentage = float(line.split(' ')[4])
                  notrec_percentage = float(line.split(' ')[5])

                  if(readTrueName(name) == correct_person):
                      if(rec_percentage > thr):
                          confirmed = confirmed + 1
                      #print('hello')
                      total_files_t +=1
                  else:
                    total_files += 1


                  recognized = recognized + rec_percentage
                  notdetected = notdetected + notdec_percentage
                  wrong = wrong + notrec_percentage

                  if(notrec_percentage > thr):
                      wrong_confirmed = wrong_confirmed + 1
      
      if(total_files == 0 or total_files_t ==0):
          total_files = 1
          total_files_t = 1
      confirmed_rate[i] = wrong_confirmed / total_files
      confirmed_rateT[i] = confirmed / total_files_t
      wrong_confirmed = 0
      i = i +1

  ## equal for each iteration
  positive = recognized / total_files 
  undetected = notdetected / total_files
  negative = wrong / total_files

  wrong_rec_on_persons = one_wrong_rec / (persons-1)

  from sklearn.metrics import roc_curve, auc
  #print("Tolerance: 0.45")
  fpr = confirmed_rate
  tpr = confirmed_rateT
  exampleX = [0.0, 0.0000001, 0.2, 0.8, 1.0]
  exampleY = [0.0, 1.0, 1.0, 1.0, 1.0]
  limitx = np.max(fpr)

  plt.figure()
  lw = 2
  plt.plot(exampleX, exampleY, color='green', linestyle='-', label='Ideal ROC')
  plt.scatter(fpr, tpr, color='darkorange',lw=lw, label='ROC curve')
  plt.scatter(fpr[1], tpr[1], color='red',lw=lw, label='thr: 0.4')
  plt.scatter(fpr[2], tpr[2], color='blue',lw=lw, label='thr: 0.45')
  plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--', label='Random case')
  plt.xlim([-0.01, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

  plt.figure()
  lw = 2
  plt.plot(exampleX, exampleY, color='green', linestyle='-', label='Ideal ROC')
  plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve')
  plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--', label='Random case')
  plt.xlim([-0.001, limitx+0.02])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Zooming in the ROC curve')
  plt.legend(loc="lower right")
  plt.show()

  print("Threshold:", values[1], "TAR:", tpr[1], "FAR", fpr[1])

# %% [markdown]
# #### CVS

# %%
def createCsv(path):

  files = os.listdir(path)
  fp = open(root_path + 'FP.csv', "w")
  writer_fp = csv.writer(fp)
   
  fn = open(root_path + 'FN.csv', "w")
  writer_fn = csv.writer(fn)

  print('start')
  for f in files:
      fp_l =[]
      fn_l = []
      if( f.startswith('log') == True):
          filev = open(path +'/'+ f, "r")
          vector = f.split('_')[1].split(".")[0]
          correct_person = readTrueName(vector + '.webm')
          lines = filev.readlines()
         
          fn_l.append(vector + '.webm')
          fp_l.append(vector + '.webm')
          #writer_fn.write(vector + '.webm')
          #writer_fp.write(vector + '.webm')
          for line in lines: 
              
              name = line.split(' ')[0]
              rec_flag = line.split(' ')[2]

              if(readTrueName(name) == correct_person):#same person
                  
                  if rec_flag == 'False':#False Negative
                    fn_l.append(name)
                    #writer_fn.write(name + ";")
              else:#non sono la stessa persona
                  if rec_flag == 'True':#False positive
                     fp_l.append(name)
                     #writer_fp.write(name + ";")
            
          writer_fn.writerow(fn_l)
          writer_fp.writerow(fp_l)
          #writer_fn.write('\n')
          #writer_fp.write('\n')
  fp.close()
  fn.close

# %%
log = root_path +"logs#10/logs_0.45_0.4_50_120_avg"
#createCsv(log)

# %% [markdown]
# ## Run Experiments
# We are going now to compare each person with all the other videos so both himselfand different one.
# At the end we use the log to compute Tar,Trr,Far and Frr and Roc

# %%
encodings_folder = root_path + "/encodings_face_videos_half/"
test_path = encodings_folder #same we use only encodings

# %%
n_enc = [-1]#encodig of the person on the server
n_f = [90]# 1s,2s,3s,
mods = ['avg']
for e in n_enc:
  for fm in n_f:
    for mod in mods:
      global_number_enc = e #number of encoding taken for each known person
      global_min_frames = fm

      performCrossedTestENC(min_v=0, max_v=500 ,tolerance = 0.45,log= True, threshold=0.4, mod = mod, min_area= -50)
# Out:
# -------------------------
# TEST STARTED
# -------------------------
# [ENC] Using encoding: rec-b1b67bbf-03ad-4df8-9857-8c9b1eefd214-kK1sKYd7uQ-eU7rCokPqbDORdhS-1581512261477-video-face.webm
# -------------------------
# The comparison last: 409.0135588645935
# -------------------------
# [ENC] Using encoding: rec-1e96ec67-13ec-42ca-9da8-1827f52f245c-yfiwiRJj6n-hjFfQvFW0xiDZ2rZ-1579801523111-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.696929693222046
# -------------------------
# [ENC] Using encoding: rec-aef670fa-9f8b-4d74-975a-4459ccf75e44-ZQtbbWSO6W-LDDwsN3cMlc8uEbj-1581515544064-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.3392839431762695
# -------------------------
# [ENC] Using encoding: rec-3511aec3-cdbc-45d7-921b-9ef9377ac954-ky7M0w48oj-JowAz1Hoq65j8Rom-1582281454795-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 12.19521951675415
# -------------------------
# [ENC] Using encoding: rec-e3f2bdb0-1ca5-4b0f-9dad-5e50b64eb363-xfevbjX3K7-s6B79p8qv6E5X1mA-1581874242208-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.409825086593628
# -------------------------
# [ENC] Using encoding: rec-120d20f3-7b9b-44b2-b1cb-a617b49a43cd-bTeKRVMj7q-YuIFzU4LfvJ4fg0z-1580220890818-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.631474256515503
# -------------------------
# [ENC] Using encoding: rec-3c6ea32b-3c7a-4ad7-8e29-bb68e6e153be-S416YvDVQ8-VxHlaySUA5Vx6GMn-1580144687236-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.50446343421936
# -------------------------
# [ENC] Using encoding: rec-aae24d0b-11c8-432e-8122-126e4ea60611-RUzrbFxkHM-Qm34q3yjV8r2KLKI-1584629640425-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.197523593902588
# -------------------------
# [ENC] Using encoding: rec-c5981b16-c9ac-4b6e-8e57-12b9551e54c2-TvnYv52mKi-X6XQExUudtf8qUBp-1582815483575-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.289593696594238
# -------------------------
# [ENC] Using encoding: rec-e85ec2ca-e1d3-4d43-ad8e-07d0473f846e-IC6WMeNpxK-els6JD2H1JyALnui-1582815617468-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.869745492935181
# -------------------------
# [ENC] Using encoding: rec-fb85a84e-f18d-41a0-9c69-a20480799701-foVmwuMEN2-JDYsRSzgWJfNTbvo-1582909649494-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.661114454269409
# -------------------------
# [ENC] Using encoding: rec-11ed9484-a061-4d69-b47e-2bed217eb329-nLhwAugvim-LrNOD5PRIWWh1xhr-1582131518521-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.532851934432983
# -------------------------
# [ENC] Using encoding: rec-aed06c29-0c35-4388-ab06-7ea3a54fcfd0-BNvb6ewlKP-UDJ9pgqYY48aYhSO-1582282300673-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.001559495925903
# -------------------------
# [ENC] Using encoding: rec-c2bb1653-3192-4160-860c-58fbf9a4996d-IrKSyAoADs-Bz1ab53dO1reBzfq-1582539710239-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.325472593307495
# -------------------------
# [ENC] Using encoding: rec-9da762fa-eeb1-4dca-8ad4-9e815c957c3b-ZnT9OgHePO-zmYTQLzXgc0jnU2j-1581513628286-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.161768674850464
# -------------------------
# [ENC] Using encoding: rec-de1c2c9e-140e-4fac-9bf4-c44923b7cb84-VRXiG3dQn7-4hpUir07qY0HTS1A-1580386096780-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.871625185012817
# -------------------------
# [ENC] Using encoding: rec-95fa7be9-57ab-48f4-9bc2-e7ad1c8c5eed-44AewlCZdU-2lpyd2xmRBanrZhZ-1580216417051-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.91096830368042
# -------------------------
# [ENC] Using encoding: rec-f98f088c-b073-4bc0-8d10-1c3e14dfd5b6-KPC7BbKy9d-2HvCqzC40urLLwvQ-1580147013684-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 11.308555364608765
# -------------------------
# [ENC] Using encoding: rec-78d7d9f2-b540-492b-a073-019a82d4e05e-oB95rzo5Az-8h8Q4nTNNbT79IfF-1582280343887-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.8614070415496826
# -------------------------
# [ENC] Using encoding: rec-4682e80b-d8fb-41bf-9510-e1d9027ac7d3-ys6CcZO5g6-DTGihNXRSBMq3F4e-1580310627211-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.083383321762085
# -------------------------
# [ENC] Using encoding: rec-e6ccc894-5264-43be-ab42-8025d2dfe121-p3GrQzRExF-vyCczKcyZ3pT3s6O-1580810860871-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.360384464263916
# -------------------------
# [ENC] Using encoding: rec-3a3c1737-1731-4e63-a926-e13e759aa26d-7qXuMA6cl4-7he8yLVpxAedu7Du-1579702917119-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.648872375488281
# -------------------------
# Percentage of people: 7 %
# -------------------------
# [ENC] Using encoding: rec-340dad65-ef53-4dc9-981f-580c288b5bd3-JunGKSfQ1N-VahVpXHetMSSUv8e-1584019913166-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.14225172996521
# -------------------------
# [ENC] Using encoding: rec-18f2ede9-5d89-445d-802e-2fab81e14c65-nPUTeKJg3r-uHOztsAUGIUAfBkt-1580745253983-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.26116418838501
# -------------------------
# [ENC] Using encoding: rec-99407a45-4a98-4892-99ca-b9012dccd5d2-9PoMhJlRpk-sAP81EXrc76he0We-1584626481847-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.7860419750213623
# -------------------------
# [ENC] Using encoding: rec-6244ff8d-42b4-4211-b985-abff0c8a13ab-9dkMwJrka6-uAFWOL5pWKoud25e-1580206828966-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.9404296875
# -------------------------
# [ENC] Using encoding: rec-24e47d74-25c8-4957-92a2-8676510befd2-P8WyAhUPXO-ElG0CTkMIcUSy6lz-1580479506385-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.659029960632324
# -------------------------
# [ENC] Using encoding: rec-2a1b8d6c-863a-4c10-b283-78de36b9cc47-4DekHiV5x6-cKxWNKKMeOcS3Jrx-1582281784989-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.7889039516448975
# -------------------------
# [ENC] Using encoding: rec-9f582e40-50f6-48db-abfb-9993fc914bcc-vFtGGbxLRc-6WFOHPmWK9KYxbMD-1584094465484-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.2244672775268555
# -------------------------
# [ENC] Using encoding: rec-88eec2a7-4c45-48cf-a5c0-ee24078b8cc7-BNhYgtjGHg-Gr7kbapKWXZuNslc-1582022499710-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.038776874542236
# -------------------------
# [ENC] Using encoding: rec-e716d72c-5d3e-4169-a058-85230184fec7-D83hBkaN96-mn3i8jTXHPyIroAF-1583948715280-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.27970027923584
# -------------------------
# Percentage of people: 10 %
# -------------------------
# [ENC] Using encoding: rec-8e3d1d7b-2b9f-4655-bd7e-2660ed4400f9-lPMtwh2U3S-r0VlA7vVhqlcdyr1-1584362907847-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.099338054656982
# -------------------------
# [ENC] Using encoding: rec-599a298c-cdda-429b-8b0b-6f12ccad40ce-M1fcHVp6yp-07PzvTBcHWCSYuaO-1582218369901-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.5951457023620605
# -------------------------
# [ENC] Using encoding: rec-bc37d16b-f123-4ce5-baa3-7d0ab7eb2ac3-QRyjeB1eCU-WaduZgNbHSfv5aTm-1581589000628-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.4927215576171875
# -------------------------
# [ENC] Using encoding: rec-8cab965e-31fc-424f-8206-6e8f56ff77e7-NBjG6RZY6z-ecFUuGOJEiVi59oL-1579878979755-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.537113666534424
# -------------------------
# [ENC] Using encoding: rec-f93e15ed-5051-46f4-8f04-bc4e2679f777-EXzlfUfYrp-CMdWuP1gfwiHEgma-1582016365404-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.663076639175415
# -------------------------
# Percentage of people: 12 %
# -------------------------
# [ENC] Using encoding: rec-59711cf9-96d3-4640-aadf-5656b56ae9e5-sVxNSYgl6m-VfDxJxwevP5rEmxx-1579689451429-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.814625978469849
# -------------------------
# [ENC] Using encoding: rec-fea00a15-9963-4889-bc1e-c3b5f6330b90-ny914bwRct-Z8h5BckVhN4wjGWG-1580914225816-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.5875959396362305
# -------------------------
# [ENC] Using encoding: rec-4fd098ef-b6a4-4747-8786-6c2a74ce1020-jdzSVfCcUI-k6hqDJU1vEy1jy7z-1581949893544-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.1166632175445557
# -------------------------
# [ENC] Using encoding: rec-7270cd7e-822e-4970-9e0c-16f11b5ae9de-0XP4p7NjlP-hQAf16keAmNzeCX4-1579769839454-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.9511632919311523
# -------------------------
# [ENC] Using encoding: rec-10b03c0e-6f0b-464d-b995-6a51710a4642-WxxOamCBHL-r9IkOZClciPMUjBv-1584013036411-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.180058240890503
# -------------------------
# [ENC] Using encoding: rec-6f362889-e6e2-45af-888a-fd2a18b3f444-19DWtcRGlL-n8QV6ueOb43DF7Pj-1582222611106-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.588151216506958
# -------------------------
# [ENC] Using encoding: rec-36370ff1-4702-456a-9c19-0e50c05b6ce4-og5JnOM4t4-M99th3oAvtgAEPiN-1579706692147-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 10.390889883041382
# -------------------------
# [ENC] Using encoding: rec-ffdf76fd-e67e-4afa-8c48-f2b1e7456e1c-PBfekMVLrw-wxMo7rKWU8aGFVyw-1580310549451-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.3009278774261475
# -------------------------
# [ENC] Using encoding: rec-95cb8800-8b25-4c6e-aba1-351fc198da13-MrR5XOucbQ-Nckrq9d4Fhx39NnV-1580811365073-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.446867942810059
# -------------------------
# [ENC] Using encoding: rec-8f0d1116-5739-40b2-bde0-59ca01d5f20e-XAwJThcQTG-5feOzheSoMMMamcb-1579689059572-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 18.279239654541016
# -------------------------
# [ENC] Using encoding: rec-c8d5f37c-b0f4-4f9b-9a6c-40ea4626a215-y6D1HFSIqx-Qwa0CyYcnrrSWs2Q-1582099213356-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.445241928100586
# -------------------------
# [ENC] Using encoding: rec-21b29bfc-9821-49ab-892b-c250c84c7675-SgKze3G86z-egyfP78COR6Fcp5H-1582794851385-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.414295434951782
# -------------------------
# [ENC] Using encoding: rec-40ddcb8b-1563-4224-978a-7bddc200e1a2-3lxRq8gnWx-LnlufTwlmeT52M4v-1580204218397-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.0804972648620605
# -------------------------
# [ENC] Using encoding: rec-1c1ab680-70ce-41b2-915d-bb6c50d57cb6-6stHYiMeSE-ZHXAqo90xJlRjwXF-1580747229480-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.771209955215454
# -------------------------
# [ENC] Using encoding: rec-15d74609-44a3-4c1a-9576-3c0f1db8e24a-k1axwh7hCr-7mOKqh1Cou9v4fEV-1580907742895-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.126767873764038
# -------------------------
# [ENC] Using encoding: rec-cac94fb1-ec1b-4de3-9cfa-dbe271146e6e-lk01tf3dCb-LYTE4dxsWcuX7tuU-1580978877710-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.926790475845337
# -------------------------
# Percentage of people: 18 %
# -------------------------
# [ENC] Using encoding: rec-4bc697a3-590c-46c1-995f-1294826e8c00-dEkTMdnjZF-MdYYqf2WbyUCOXWI-1581511319906-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 15.600327491760254
# -------------------------
# [ENC] Using encoding: rec-49529378-1374-4064-9867-ceb2e009bfdf-G0I1modq6y-aof5uIQkJEY5s6tY-1579690330698-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.271232843399048
# -------------------------
# [ENC] Using encoding: rec-950c01cb-9cee-46fc-a8ed-365356d46205-XrGuImZsAM-bHspLAH0Jq4gZX3K-1580458876514-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.880379676818848
# -------------------------
# [ENC] Using encoding: rec-b9436aa1-e1cd-40e9-853e-080c95a51910-Xph7XlZg3G-7VZXRgUil1MoaegZ-1582534229608-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.69485092163086
# -------------------------
# [ENC] Using encoding: rec-82045d32-3e89-4586-85d4-d6a177dd59bf-EMKNTceSKa-BxzfDdsL5k1EcjQG-1584122360904-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.1779625415802
# -------------------------
# [ENC] Using encoding: rec-a031b257-7ba2-4144-a4d1-1a904039fc43-0D19bdIpmy-sb2uRAy54UFd0nGH-1581871731786-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.2352399826049805
# -------------------------
# [ENC] Using encoding: rec-a1d731b4-f948-449c-a8a6-5a3ee7e942cc-t8sFDJuUdV-DsZtn6VKMNmXdS4N-1579877623535-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.1645588874816895
# -------------------------
# [ENC] Using encoding: rec-e18eaf40-0175-4f20-bba9-e34e97f33043-EiINdg1UGt-Dn78motetcG3T34R-1581589569715-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.207555770874023
# -------------------------
# Percentage of people: 21 %
# -------------------------
# [ENC] Using encoding: rec-b4679217-8ed9-4d9c-b487-3d66fdc10028-gemqg7s10W-8dWXxzy6TbbDQ7Ta-1582808653491-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.426553010940552
# -------------------------
# [ENC] Using encoding: rec-6b7a4334-ab39-49c9-a02c-0357e37e88ce-TyRtMC1ZGB-61gO8NEFXN5lf6su-1580389835102-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 12.15600872039795
# -------------------------
# [ENC] Using encoding: rec-893d39da-4cd3-4b80-b15e-7500969b3b89-j5ZyprsLBM-lJofzqzmefGANkhi-1580752083474-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.770707368850708
# -------------------------
# [ENC] Using encoding: rec-284c77a4-69a2-4008-8ff5-57e62b8c61e7-KYD5H24CUv-A5E3B6r14GS6EQ0Q-1582559398359-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.200631141662598
# -------------------------
# [ENC] Using encoding: rec-b5e24096-ac14-4554-b17c-1a100e5c28a6-OJHBQ62w2Y-6AMQbk4VZKvPAflM-1579690744526-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 11.365782022476196
# -------------------------
# [ENC] Using encoding: rec-def2f69c-473b-4366-ae0a-45ef3021e97e-LVOtA8QOui-bkDdGG8vMZMZkHRx-1579620743313-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.53323221206665
# -------------------------
# [ENC] Using encoding: rec-a3b9dad3-8526-4957-be1f-940365931761-qTb1aE9pbK-tcIELcACbHJUMmWL-1581589770161-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.861984491348267
# -------------------------
# [ENC] Using encoding: rec-2b537329-2644-4d4f-a121-2e2fa3c8993b-D09niKq4hz-9gljAWsPrmXs9w2u-1579877546041-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.276116847991943
# -------------------------
# Percentage of people: 23 %
# -------------------------
# [ENC] Using encoding: rec-b67fd255-a41e-4126-8868-23a89c14504f-5uLvyqdDxn-udcVzM2uwObc9AZg-1580203982761-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.468963384628296
# -------------------------
# [ENC] Using encoding: rec-0fb5c3ff-b834-4b19-99d0-59dd489fb0c0-JPkc9rlYPU-xSRtCzhE7mBzNvyK-1579620321313-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.164605379104614
# -------------------------
# [ENC] Using encoding: rec-e27ac333-be12-4e02-8424-9bb85571311c-bPcVCvxuDe-K303f9qjeqfpn6sP-1580836449884-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.9592456817626953
# -------------------------
# [ENC] Using encoding: rec-4537169a-78d6-4448-b648-424a6bb54d83-ohEPHhUcXk-brva4wDuKsaPvypy-1583847335994-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.43224024772644
# -------------------------
# [ENC] Using encoding: rec-029c7345-eb65-4b22-aa68-4c7ad814ec4a-YYWgaS5LEb-Wfw34uhRwl8rKOAa-1582738555620-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.963114023208618
# -------------------------
# [ENC] Using encoding: rec-1a838b52-0cd2-4c25-b90a-332bd7e97b33-2O4W44PhGu-pl6x9USbPCFdMmv1-1580309779647-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.230816125869751
# -------------------------
# Percentage of people: 25 %
# -------------------------
# [ENC] Using encoding: rec-8e763c87-cb4a-48ad-9b51-904b3d010c4a-7WNP6byA9P-H5ZADhcXpZJL0Jco-1582022772848-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.810979127883911
# -------------------------
# [ENC] Using encoding: rec-3922b436-d56b-4666-8ba8-763ecb17900a-C1QDts6mxI-xZMwMkYpVkinLcAA-1581583764187-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.746513843536377
# -------------------------
# [ENC] Using encoding: rec-4c542b14-af01-4bb0-9801-160c6ecb3995-vCdgzbMLoS-zds0NsUS6cUNr1Bl-1580813624338-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.497361421585083
# -------------------------
# [ENC] Using encoding: rec-58c61d80-78c0-4843-bc95-075cf418dc88-ApR9URoj8C-Lp1DCnoqdLxRA2gG-1582273758038-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.437174558639526
# -------------------------
# [ENC] Using encoding: rec-60c268c3-5aa4-45ed-b90b-cba009ba4dd1-ZiIwSqDIqa-gy55stRFTmbsT06M-1580297723501-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.601903200149536
# -------------------------
# [ENC] Using encoding: rec-2bf32730-ebce-4c7c-83db-5b26090c044b-K7iXbGDGzQ-w4bitGNjSsk7EcqW-1580389492310-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.8242409229278564
# -------------------------
# [ENC] Using encoding: rec-e58922e3-f5f2-44b1-a814-ddee979f685b-jjISg69Mmr-EkSos64lMdXSKsfr-1581957438231-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.6972668170928955
# -------------------------
# [ENC] Using encoding: rec-4b6a6f4c-1d1f-4d75-a071-f7a27627d352-1WWFEzLJcU-3DxW70qOggkSPD7h-1582887891897-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.191118001937866
# -------------------------
# [ENC] Using encoding: rec-b937f1df-34ae-470d-bf1c-33161cc8901a-Pm7HlOjl0c-rSQ5prb28z6DvYcX-1581964072964-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 10.42276668548584
# -------------------------
# Percentage of people: 29 %
# -------------------------
# [ENC] Using encoding: rec-3a1eb40b-9601-4aff-b3f5-b154e53b9efd-1rv3xi7f3n-eWg3wpTZc2MeJP3r-1581524498309-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.883596181869507
# -------------------------
# [ENC] Using encoding: rec-b631d53f-e08b-424e-b7db-11527bff2872-9E4ReINFtt-QmNEl5f0G0k66zuV-1580380542298-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.223661184310913
# -------------------------
# [ENC] Using encoding: rec-cd044341-42a7-4ce7-9d86-2643c613b4ae-fSk497wZg5-bzBIfJnbS09rDwFT-1580204724180-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.058889389038086
# -------------------------
# [ENC] Using encoding: rec-d5cafde1-7be7-49c3-8e0e-ed8e83264c49-AlG4fvzSkT-eZAFaBqqOK1ut6Sy-1580389274443-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.244471311569214
# -------------------------
# [ENC] Using encoding: rec-f48bcdfe-738b-4d14-be97-e08afefed91d-BSF4Esjbpo-RcMK9yXxYlD6aNuh-1583486051914-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.712265253067017
# -------------------------
# [ENC] Using encoding: rec-156f1f38-84fe-4616-aa31-4f0d3c7c4553-ghTurKWRWQ-0fy0fIW0Q17UIBG4-1579596711801-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 13.753222942352295
# -------------------------
# [ENC] Using encoding: rec-03d368da-4518-42d2-8101-f010b0b7351e-VOG8HPCfbf-TeLbDVoK3J89n8Bx-1579700447393-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.3587000370025635
# -------------------------
# Percentage of people: 31 %
# -------------------------
# [ENC] Using encoding: rec-f6b2fcbd-a448-466e-b796-80b0b228c046-1LGlRGmnlP-AoolUMTkQwr1SrgY-1581511697349-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.529790163040161
# -------------------------
# [ENC] Using encoding: rec-1292da1b-640e-44e9-b53c-8cd4657990af-WL0QRQDG4D-FYgTYITePKMwzRPT-1581690492071-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.848905086517334
# -------------------------
# [ENC] Using encoding: rec-cf41e27d-2f71-4997-94c1-2a654c1350b8-2U8yb3WOQ3-rx19EPRCxkc4yrBo-1579770642964-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 14.437612771987915
# -------------------------
# [ENC] Using encoding: rec-aae40477-87d9-4b44-a625-5d12871787ae-q8f3oUbmdT-gpyG6MQq6MSjmdHT-1584543536765-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.8174097537994385
# -------------------------
# [ENC] Using encoding: rec-f54ac722-fb0e-4ed1-bfbd-f7ac22ca48a8-aZ7ivK9xte-Yp7I6w0tEmZEaNA0-1584105013919-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.916080713272095
# -------------------------
# [ENC] Using encoding: rec-44124b0b-e6f9-4071-9b39-b7cf2eccd3c9-QmIT5XCjxy-iX88qnpNUD4pmZLn-1582283183906-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.148536443710327
# -------------------------
# [ENC] Using encoding: rec-6d46cbb6-9467-4511-aba8-c94aa6d74933-pnBNI4JT7E-b1e8xOdAfJTUzNsH-1579604529259-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.0661683082580566
# -------------------------
# Percentage of people: 34 %
# -------------------------
# [ENC] Using encoding: rec-75804713-876e-4120-808d-d74d81a21c1c-TFTIv7MMlQ-tIJ7pBzXzUSKtt3L-1582724911755-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.924312114715576
# -------------------------
# [ENC] Using encoding: rec-726b9bb0-e0dc-41da-9545-0c4ffe37fb64-Z7D93vBA4C-GEIkCxSpMDS63DhO-1581440306831-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.281686305999756
# -------------------------
# [ENC] Using encoding: rec-1a8c6bed-ebb0-4167-9c86-293d5fc5a12c-84pDQjlMXW-0P9fuZjlChhk0vDE-1582559205412-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.055497646331787
# -------------------------
# [ENC] Using encoding: rec-6cb61ee7-b345-4290-bd81-7305874cd574-c1GmIuXAuX-6QVRwXPUY4eDI4HM-1580900906505-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.008582830429077
# -------------------------
# [ENC] Using encoding: rec-99d4335d-1ead-4c4e-b0dd-ddfbab3b94e0-EZZjV311PY-xLA2dvdG90YbnOJ2-1581875240128-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.484233617782593
# -------------------------
# [ENC] Using encoding: rec-067059d0-de36-4cba-b582-767018c81649-CD0BvfsA9d-6lIbXosg5MwAF1WL-1581590355281-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.814174652099609
# -------------------------
# [ENC] Using encoding: rec-249f6d8f-2abf-4e6b-a178-29df2e52a334-BwAJCCOPdu-OEpcicghW2crbBVl-1582217940950-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.4791693687438965
# -------------------------
# [ENC] Using encoding: rec-cee71b5d-8fad-4799-96a7-6ff98d8a3364-ou7FdjSS28-D4X1DD9d0Ri9wENm-1580320432727-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.295768737792969
# -------------------------
# [ENC] Using encoding: rec-c6f15a4a-1704-43ef-8a45-8509df37f151-7e1EOKA0Xd-8pKxblniZVksgp10-1581951947323-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.556903600692749
# -------------------------
# [ENC] Using encoding: rec-f0c023c3-af12-4956-af30-73a129c195a9-xnXFFEmVVn-GobT7cNSMLnWPR70-1580840114060-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.57594919204712
# -------------------------
# Percentage of people: 37 %
# -------------------------
# [ENC] Using encoding: rec-e5b3fa94-d9bd-4541-84af-254846ac03b1-FOBAMOkoL0-jDYEGkLkMeMPCaeq-1582279663465-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.573337078094482
# -------------------------
# [ENC] Using encoding: rec-33ef9576-1aaf-42bd-9efc-6341a1ff3fe3-Dquk8t8vFJ-a1ptgtuq6SniNgN3-1580226977654-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.527665853500366
# -------------------------
# [ENC] Using encoding: rec-2f071007-bd43-4be3-af6d-aad2f8c3b785-nP81x9TeEr-Ba8jxPEDrZd6Lp8W-1582023230350-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.051483631134033
# -------------------------
# [ENC] Using encoding: rec-19e0fd45-7b91-44c3-a3ab-d3f4727accec-2WtkPwyEp7-8mh1lhQbcYPSY12J-1580926423516-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.427431106567383
# -------------------------
# [ENC] Using encoding: rec-abcd1b0d-a2b2-42da-a645-e9986b14fa30-KPnxEblfnb-u86ALUFCr9qnuQG7-1583416906665-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.983996868133545
# -------------------------
# [ENC] Using encoding: rec-438349b7-9f8d-4a51-9ecc-4da46ada2356-9CtmAgoXnM-MXKFWYYTZNmpaVGF-1584099197873-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.221579551696777
# -------------------------
# [ENC] Using encoding: rec-3bb010a3-d5b5-467f-82ca-93c47057bc34-seV7w6QIqS-dRjFJ4YLzDQVxtDK-1582652121071-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.132388114929199
# -------------------------
# [ENC] Using encoding: rec-26373d26-08aa-4e56-8908-8d68f88f04eb-0XmimUxM36-SdXdXnFtg0maWmlg-1580890992994-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.7522175312042236
# -------------------------
# [ENC] Using encoding: rec-36aaefc8-f13a-4b4b-b8c0-eac941f361ff-jPQ5U6qkgH-j0cHzoXD4J935eln-1583229627124-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.767468452453613
# -------------------------
# Percentage of people: 40 %
# -------------------------
# [ENC] Using encoding: rec-c6822335-fb87-484b-97d3-fec98a3fc196-r2JRbO2JMF-ENi10YLlMs2iKIZH-1580391078755-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.9037184715271
# -------------------------
# [ENC] Using encoding: rec-1e26a1cd-848e-491b-a9dd-86b7b709595d-dWlXe9EeDd-NkflnlHbgyWZRoEZ-1582023873325-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.42041015625
# -------------------------
# [ENC] Using encoding: rec-2582bf5c-13c9-4653-8ed6-5e692b4738ca-6PFkJbIJNd-WEkBav0p065GCYU7-1580228880755-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.435816049575806
# -------------------------
# [ENC] Using encoding: rec-36839cb2-4bb6-4fea-9d63-2f49c90893c0-ve6Znpj0Eb-wvWjZCBKgAYc7OL4-1581690853008-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.463834285736084
# -------------------------
# [ENC] Using encoding: rec-65e91c60-135d-41af-b754-8edb4f1a06e6-98aQceHuqo-4SJ5Gg1Qz6luxhIe-1580295826484-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.5843963623046875
# -------------------------
# [ENC] Using encoding: rec-0158e178-671c-4f00-9d2c-4beb850fee5e-3JMlpKKcQI-AbKReuhN2e8lPpWU-1580377499206-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.309518098831177
# -------------------------
# [ENC] Using encoding: rec-5e162aea-4e62-4cf4-ade2-88305b077322-bI1hXod3al-8VctOHBqWoimwbow-1580889730215-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 18.28842043876648
# -------------------------
# [ENC] Using encoding: rec-fcfe0a39-e39c-43b4-b079-c33d8b32e1fc-xbuGTLAQtW-rxttubgxiVt8HPxV-1582559394139-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.683469772338867
# -------------------------
# [ENC] Using encoding: rec-ebf85f65-a061-48eb-ac88-730958af0573-p0yhXlnCi6-6wg2sPRHTJQvYpYC-1580214153974-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.957153081893921
# -------------------------
# [ENC] Using encoding: rec-79450fe7-20f9-4d44-a5cd-1cdc3c689928-5ZLilOg7hl-MFrcDAooY6Nt4GOd-1580920063086-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.2483904361724854
# -------------------------
# Percentage of people: 44 %
# -------------------------
# [ENC] Using encoding: rec-b248acd6-c7d2-4406-a43f-3fdd97d35ea3-zWS8oWCjsu-Ja45t15OLDEru2aM-1580235635066-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.787663459777832
# -------------------------
# [ENC] Using encoding: rec-24eb12ee-21a6-4219-b901-9b6a59d84d4e-BiieOGNniw-rhvrr7NkfGOt1FDl-1583848507688-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.441760778427124
# -------------------------
# [ENC] Using encoding: rec-5156815d-ed28-4762-8fd5-98bdd89be695-WsInqixvM6-DLJjlhUQcpsYM55a-1582905746888-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.2253944873809814
# -------------------------
# [ENC] Using encoding: rec-0048614e-6977-420f-96b9-2669e01b7b6a-xtlT3wU8hU-qR5OTs6cT0MYV1dP-1583832656032-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.065614223480225
# -------------------------
# [ENC] Using encoding: rec-60cb827e-d2d4-418e-a1da-855d9ffa6a74-mGGxdwjk7n-FW2Ls59dcYo8SOUo-1583426703031-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.847886085510254
# -------------------------
# [ENC] Using encoding: rec-c1e08043-181c-41a8-8313-45510b311074-ottnm6lvcz-H8pCWFyvPHb4tw5r-1584365213226-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.533011198043823
# -------------------------
# [ENC] Using encoding: rec-a0659b8b-4386-402e-8f61-149e413cf095-ccBcnp4yFX-vdGT0I5lfiLDlEqt-1582217383898-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.312553882598877
# -------------------------
# [ENC] Using encoding: rec-bc04d5b1-c304-429b-a954-16da5f316c72-ktqM8IlskG-VrmsXywf2Q0WjNi4-1582014723949-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.291059732437134
# -------------------------
# Percentage of people: 47 %
# -------------------------
# [ENC] Using encoding: rec-61755aa4-2178-43bf-ace7-8717b7013cc7-BypLWctgTT-8OIA3np77WlU4KB7-1580982236050-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.489995002746582
# -------------------------
# [ENC] Using encoding: rec-2a435836-1c12-41b3-95d6-ae48252cd59b-oKZxZc6ffr-jGkIsjyJ2OTGHBgD-1582294822238-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.628267765045166
# -------------------------
# [ENC] Using encoding: rec-4937a07b-fbd3-47ed-9834-8b962ffe2248-fWof33JzvK-1Lt2pnuPDIqXrmLi-1582794940561-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.12239408493042
# -------------------------
# [ENC] Using encoding: rec-0b8d8a2b-71fe-4f11-b821-74d4c097129f-e1v6aDlXNy-0IU1qUnlMtxDds2R-1582098770323-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.672174692153931
# -------------------------
# [ENC] Using encoding: rec-3d102de2-4e40-40c8-bf36-f2b33512b427-4PCIU0O1K8-Nmda0iRqAPaoLX9h-1580204324244-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.987378597259521
# -------------------------
# [ENC] Using encoding: rec-5acf8171-e020-4c1d-a3a2-50d6d584e818-9mpo4PlqiP-aFhziSGndO4qm7P3-1580981069658-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.773660898208618
# -------------------------
# [ENC] Using encoding: rec-c444b96a-e256-4bc3-a9a7-14735a26f763-t31xibVJvY-HE2O16mtU9oqPA24-1582906683568-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.662295341491699
# -------------------------
# [ENC] Using encoding: rec-e7ec15fe-4f61-4997-8837-c7f415738b88-FMgouDroXW-8Wb9D9r0A1rfj0wL-1580744714412-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.251488924026489
# -------------------------
# Percentage of people: 49 %
# -------------------------
# [ENC] Using encoding: rec-a28b1329-b403-4ee1-8825-1ddd94310701-7GhLbaMK4a-6kFCo2dQG3UKI8nq-1580224914998-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.507453441619873
# -------------------------
# [ENC] Using encoding: rec-88c47b9d-c189-4c88-a8f3-1b6901658681-ccrmLz5ydb-LtPCbyjBFjwDHLPc-1581693592821-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.374027967453003
# -------------------------
# [ENC] Using encoding: rec-d88fa51e-4cd7-4fa7-80de-db1ffc6b3c16-iYofsn6u8H-qK8JBaqrr9tyLWQD-1580309612245-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.497128248214722
# -------------------------
# [ENC] Using encoding: rec-38e0a246-3460-4971-a98c-9b2e93e7f875-qYuRStVzb7-FexNAv0V6caqKNRf-1579630565201-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.41237211227417
# -------------------------
# [ENC] Using encoding: rec-7fe1e063-1e3b-45ad-bd63-fbeecd06036b-prwTQwRVtr-1b7clk24GiKEo116-1582808994518-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.545223712921143
# -------------------------
# [ENC] Using encoding: rec-b170878c-1527-4fee-9538-a6769a814630-I54DazYhHl-PqMUbltd0DvhODmj-1582130172928-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.815979480743408
# -------------------------
# [ENC] Using encoding: rec-b5a8db4d-2ad5-491e-8564-bd280bf68145-CnUsdXvNH6-QN9wHToBOZ1miIGW-1583317350607-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.3916239738464355
# -------------------------
# [ENC] Using encoding: rec-3d96f165-7d2b-4647-b8c8-7d55d13dc654-L6dC1hbG7r-juWwNjM86TChX3zD-1580220037177-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.322229862213135
# -------------------------
# [ENC] Using encoding: rec-d0e5a0eb-240e-44a9-b016-724e2b55120c-NfxG4QP68U-vC4uXip5CkHmVdsy-1579508621406-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.716385126113892
# -------------------------
# Percentage of people: 52 %
# -------------------------
# [ENC] Using encoding: rec-5d18d29d-6464-4884-ac3e-f89e118b7c12-bYOzxZr5du-Uod61OF3ddgH41uY-1583247677719-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.648426532745361
# -------------------------
# [ENC] Using encoding: rec-cbfd710e-57b4-4b89-bd97-91d0954ab152-GnoSbPZDeL-5qu45MYRqMUP7L9G-1581939807404-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.641298532485962
# -------------------------
# [ENC] Using encoding: rec-50edee52-a410-44d3-a45b-de8d2cecc661-WhwMci3udo-b7dWINqS9x064cw8-1580204477086-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.945948600769043
# -------------------------
# [ENC] Using encoding: rec-03379460-9227-4a18-bc4f-5b6add8889e2-t9YIugGYEF-9ychy6UfJvPIuQhr-1583412789808-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.454035043716431
# -------------------------
# [ENC] Using encoding: rec-f2b3921c-ded9-4236-a694-6e57b9154a68-x6WD58qXe6-eTTiiOMidZ88zXLt-1580145134608-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.587966442108154
# -------------------------
# [ENC] Using encoding: rec-fe443a14-202c-48c7-afa2-91646954ddc9-Qu04RzRtsH-oNxJZ6m86LzIiZhN-1582720713340-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.458008766174316
# -------------------------
# [ENC] Using encoding: rec-0b5b25aa-2a06-4e14-83ae-4f197fd6a754-n8h1fus7Ri-UpRtkMFrcjGM3fLb-1582045799142-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 10.857645034790039
# -------------------------
# [ENC] Using encoding: rec-f393a22b-67d2-4539-acef-fa616767110d-SMluX2iWKc-8xHIbnZT6OiQv5ZN-1583141851912-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.3637676239013672
# -------------------------
# [ENC] Using encoding: rec-a95756bb-198a-4a4c-b5fd-d33e2e896ab5-gfD0VWPKCY-4kW9b9GeZlH4POBS-1581935959284-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.4286222457885742
# -------------------------
# Percentage of people: 56 %
# -------------------------
# [ENC] Using encoding: rec-8f868b0c-ca75-461f-9b1e-a7a6019a6624-HQmsKDjuGk-M6SMxJNEofjiRk5C-1582886778029-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.4881064891815186
# -------------------------
# [ENC] Using encoding: rec-0443dcfc-bca0-4a21-904e-7a9d948e873c-fmfXOCBSnf-xgSFXV1VsTFagavZ-1582046330299-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.668969869613647
# -------------------------
# [ENC] Using encoding: rec-d158f009-b61b-4be3-a058-d3f4f5cb4735-nQwBQQBuTd-KtOrikAEGqHKtwLe-1582652656602-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.7580530643463135
# -------------------------
# [ENC] Using encoding: rec-1c6f93ef-a39a-4b1c-8f17-8fffd3499a40-Elyq0oiYZV-c0H1LIJpTLocXLog-1582538355355-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 12.69602084159851
# -------------------------
# [ENC] Using encoding: rec-2e13afe9-5552-4301-ae59-cb717f2f4d04-9vJMIfjGWl-J7xFYgceW5Rwj5iS-1583431415330-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.0789408683776855
# -------------------------
# [ENC] Using encoding: rec-2316b55c-43b3-497d-915d-895e973b5bce-JWSVXDV0hE-ICqehbS9iOwtrDr7-1579601029619-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.1101438999176025
# -------------------------
# [ENC] Using encoding: rec-803b998b-f8b3-4b39-892f-18a655a21b57-knIwLpmzF9-lKPU8UOHnYvokEKY-1580750750137-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 10.837074041366577
# -------------------------
# [ENC] Using encoding: rec-46b1114d-3ebc-440e-99d2-02fc86d6e396-6aRMgEdSjq-y9EHfzQ5KyVHxZI0-1580220452451-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.411264419555664
# -------------------------
# [ENC] Using encoding: rec-ee365ca8-914e-489b-a95c-9093f584501b-QVh57YWwOF-pbWr9UznnswPjqhM-1583402854229-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.145273923873901
# -------------------------
# Percentage of people: 59 %
# -------------------------
# [ENC] Using encoding: rec-b97f7930-869b-4371-86a5-d802a3375a37-XAgNwZRd4i-pU1mt5lp93KD7Crk-1582221369370-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.719271659851074
# -------------------------
# [ENC] Using encoding: rec-7756ce8e-0dc0-4f18-a231-352104d023e1-F3PAy48D8B-iS8lSR14ZDbkI9Iv-1579702511178-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.1309685707092285
# -------------------------
# [ENC] Using encoding: rec-6f1be72e-5c73-401e-8093-87079c6f93b5-fzcKe1HEz2-3Qr9olRL6Uj03rXB-1584633817109-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.001437664031982
# -------------------------
# [ENC] Using encoding: rec-6a64dbe5-2e78-4299-a0a7-b13449b935a4-xEoHk7KC73-TBXVhzpEvOo9kxNU-1582023261677-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.308755397796631
# -------------------------
# [ENC] Using encoding: rec-1e1e84c9-bbb8-4933-9d71-83adecdc9c55-XvrWEkYuHN-5gXGtz1bZLhxkPAI-1581935757746-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.396216154098511
# -------------------------
# [ENC] Using encoding: rec-3ce87cbb-f20d-4b4f-81f6-02ea1ed08ca3-PWHKOUMrxD-KAVAljab83XXiz8v-1582815803689-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.687474966049194
# -------------------------
# [ENC] Using encoding: rec-4ee784c7-3480-4ee4-a72c-a0e06817f241-3sKFCoCHLH-QC80MiarInEm6vX0-1580463575852-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.477227210998535
# -------------------------
# [ENC] Using encoding: rec-5de1bdff-1318-4161-8847-b763dcf5c7d5-2jnhsnMfhb-OjCrbPABhu8SROFS-1581589128955-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.4992756843566895
# -------------------------
# [ENC] Using encoding: rec-e8261b18-109c-4f5f-aec3-4246d4e46136-Vg2qS8fqFO-lDQYQELavcJyRd3J-1580744956809-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.426911115646362
# -------------------------
# Percentage of people: 62 %
# -------------------------
# [ENC] Using encoding: rec-24898481-db3d-4f3c-a3e8-d45b4288c4ac-Uls6bJYNbf-f4lxz1p5o1Rl9w2y-1579696858072-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.899943113327026
# -------------------------
# [ENC] Using encoding: rec-05281cf8-222d-404e-a54c-c71b2c647c1a-LyiWaWvwP6-mJ2PGAYhxhJrJLkB-1580228529216-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.498572587966919
# -------------------------
# [ENC] Using encoding: rec-cf2cb23d-7d7a-4e2e-8bc9-7b15a5ba364d-vcdNk32Xjz-G0eUAGasKWH4B1pm-1580983911961-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.075556516647339
# -------------------------
# [ENC] Using encoding: rec-78e2c327-a3a8-488f-a898-8d3dbc264d94-sBlfVZBDBS-ybkVc5skoS2WNwaT-1582280786117-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.23068380355835
# -------------------------
# [ENC] Using encoding: rec-fd959e5d-b7c4-4039-93ee-e9c8147d36c2-mApXVQ8be4-wktafYoNQUxy6Pjb-1581516176579-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.227555274963379
# -------------------------
# [ENC] Using encoding: rec-19600fcc-156b-46c2-b00f-0da563964ab2-WcDkYRC8DH-KbokaIILLOfpscdO-1579707788610-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.4590981006622314
# -------------------------
# [ENC] Using encoding: rec-7a6d2ccf-ff03-4fa9-b01e-799372bc5f67-JEJ7BfcZi2-ogyFiV2KaWJ8AUbW-1582725020918-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.188690423965454
# -------------------------
# [ENC] Using encoding: rec-c00d5a28-7aab-462f-90c8-be81f2f3df4e-Kfc9rOotmU-r1MJsR8D0es84qnT-1580144586679-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.264346122741699
# -------------------------
# [ENC] Using encoding: rec-309dcb03-4187-40d0-8249-b854394c16fd-RokVDauTQ9-N2jRnKY3dRrsUhO8-1580297244525-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.393843173980713
# -------------------------
# Percentage of people: 65 %
# -------------------------
# [ENC] Using encoding: rec-c8368152-bf95-4f3e-b000-3d332e3b0d38-gXOX4rTYhI-53vyAzGlc4tpo7Ql-1581937252394-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.134988784790039
# -------------------------
# [ENC] Using encoding: rec-8b14f723-fbd2-4457-9f5c-eab7fd201843-z49Iy3iWyo-0Kmr4tcYjLH70Hv1-1582625472503-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.705383062362671
# -------------------------
# [ENC] Using encoding: rec-da200039-ac71-4cc0-b2e2-efaefe660983-0OgLnMWQAK-pG8t96dPHQtV3jhP-1579595468787-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.558412790298462
# -------------------------
# [ENC] Using encoding: rec-d580d699-30ee-4891-a858-f99408b26fa9-sGljnmQjY0-Ws488UqSDXnfSdr4-1580899320063-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.736878156661987
# -------------------------
# [ENC] Using encoding: rec-b41f82b9-70c3-40b8-b09b-50682543e4ea-yBYz6WV2Tn-VN1EWMQ2IrpZxhZE-1582219816311-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.57638692855835
# -------------------------
# [ENC] Using encoding: rec-ad69d356-344b-4309-ae3e-f05e95d79866-NRmUrNDe1O-JX89B46tRZAPex3J-1582279924643-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.432356357574463
# -------------------------
# [ENC] Using encoding: rec-1c67dd79-3dbf-42e1-ac6d-f7415150b840-iqIU2Jm1zS-MWvpnsvvOORXsWb5-1581526562348-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.20510196685791
# -------------------------
# [ENC] Using encoding: rec-17953474-6ebf-48ba-89db-5c7400b9fd6a-mMbWSGCXC7-h6i3zBWw8yKO7v0H-1582024433597-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.4216837882995605
# -------------------------
# [ENC] Using encoding: rec-c877b98a-4184-4aad-af05-40588a02a9ac-kurxbCkzg8-B24Tj1GwKytonFzX-1581938568675-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.7944891452789307
# -------------------------
# [ENC] Using encoding: rec-74288b73-8b01-4d4b-a683-889333def62a-gSX2OJiPc8-cVcvzks9lTkEEJ8n-1582534569377-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.357741594314575
# -------------------------
# Percentage of people: 69 %
# -------------------------
# [ENC] Using encoding: rec-a3fedf5f-2868-43b4-b51a-2fea60fdc5a0-SzhBhZlJJe-8kWbi5EVTA6QmI8S-1580919404886-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.9740467071533203
# -------------------------
# ...
# Already existing folder
# -------------------------
# The comparison last: 4.12818455696106
# -------------------------
# [ENC] Using encoding: rec-caa37120-7680-47ca-b174-b444969d3c30-aBI5pNErIg-6mDmab85GtYvhc27-1580204173378-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.2483298778533936
# -------------------------
# [ENC] Using encoding: rec-a7466c71-16b7-41e2-a970-1bedb7619940-Nenkh07mvk-IprDlEfqCvMLOonB-1580383805260-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.943379402160645
# -------------------------
# [ENC] Using encoding: rec-4de496a3-e342-4228-91e0-1b02a56e10b9-IJLu9RjLKp-KmLETWKDh7yLf1IA-1581602029164-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.2559621334075928
# -------------------------
# [ENC] Using encoding: rec-fc3e758b-721c-4b15-9767-32b85f538115-m5WEZs1rqb-6Y5ZplI1HQYT1Roz-1583225430427-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.714564800262451
# -------------------------
# Percentage of people: 78 %
# -------------------------
# [ENC] Using encoding: rec-2c6e1f97-f7ab-4204-b6d2-7a9d877de1d3-c64caTsDnk-4L9xnu2sQ2znTN2T-1583957092797-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.866629600524902
# -------------------------
# [ENC] Using encoding: rec-ec6c0622-a791-448a-a9fc-9d5aa9f727a3-7xjJVWRGru-m72M4lxyfK8tyhis-1582801255712-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.747379541397095
# -------------------------
# [ENC] Using encoding: rec-ad13298a-ba33-4aa0-8beb-f73d5289c6d0-lId0gao4i1-ar4uxqLtCkfY7Yvw-1582045440169-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 14.01331901550293
# -------------------------
# [ENC] Using encoding: rec-80b975c1-1d2c-4859-a44b-119ea11de9ed-wmi8fscdeC-wrpjjGHPKuIqYm9I-1583837978315-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.642093658447266
# -------------------------
# [ENC] Using encoding: rec-de9094b2-9391-47bf-afc2-a90242d759aa-cEvaNBnbXP-R2EDyD41kJhwL42C-1582909132267-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.92146897315979
# -------------------------
# [ENC] Using encoding: rec-48875432-a7e2-4e69-8ba3-af8083bdf340-VzauCHQi5X-ksPAZc0kesv5osvH-1580839869612-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.363654375076294
# -------------------------
# [ENC] Using encoding: rec-2aea2716-5a79-41c4-94e5-386551491de8-DcNm1mqDUy-SvUAx0jOjRJxUjF0-1579690811823-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.312859296798706
# -------------------------
# [ENC] Using encoding: rec-7663af3a-7861-4421-afef-e3d53a65bf0c-zuoaoDu1Y0-ixIDXYOsw4zuHwQx-1583413554448-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.13986849784851
# -------------------------
# [ENC] Using encoding: rec-54ae5027-256f-4ee5-a46b-223c384b0182-zm54FH6Emd-UGIcAMTqaPHCbzcb-1582882369406-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.992334127426147
# -------------------------
# [ENC] Using encoding: rec-1bfffc4c-678a-48fa-9d53-d17e8d71c9a1-1Y2XAnvhCP-tL8XWbXPrbmVowyg-1579697128993-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.549164056777954
# -------------------------
# [ENC] Using encoding: rec-050e98c2-1087-411f-96e9-b55e6bb3d268-VPOXpy4gJe-9q1PY2HVRJmo6MTK-1583414277942-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.153881549835205
# -------------------------
# [ENC] Using encoding: rec-887c8603-7206-4ccc-8717-c11267a9e966-klnYVYtODo-rzmsvqAJ8xMlszgq-1580237348494-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.625454664230347
# -------------------------
# [ENC] Using encoding: rec-b8b6dd4f-d57d-45ad-b0aa-19cd47baa410-DShHqPGa9M-wH081WkwGS0T7bwc-1580309908256-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.098907232284546
# -------------------------
# [ENC] Using encoding: rec-25930e98-fced-4e8c-bc6b-5c6f67f21d13-Wns4EgnVnP-DbtTEgDsJRvka34B-1582803428861-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.7197816371917725
# -------------------------
# [ENC] Using encoding: rec-e056c41b-6ff8-4561-80de-c1d31554df94-wETIPI7avG-Nwsv9jqnVc3u18AF-1581932298946-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.032125473022461
# -------------------------
# [ENC] Using encoding: rec-6b130365-db65-4bf6-94d8-f1fc4a1d98d6-gNWW3iZ40T-a5eOOFLWkHbb8nEU-1581668563361-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.863552093505859
# -------------------------
# Percentage of people: 83 %
# -------------------------
# [ENC] Using encoding: rec-d2cb4fb3-c5ff-4e6d-a100-09970b78c5f1-U8MGFK6DYW-3wbE6qBOmGLZXoz3-1579689079530-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.399654865264893
# -------------------------
# [ENC] Using encoding: rec-ce84b4fa-b47c-4d0a-943f-293af854c7ce-RdVxf1ubwV-ZRBJUqxnqs7fD1f4-1579773115095-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.961021423339844
# -------------------------
# [ENC] Using encoding: rec-2cffa950-2ba3-47e4-b988-d8b7200af4a7-jxDxANoPND-JjHK1kDBYL21cjub-1580403380855-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.8729050159454346
# -------------------------
# [ENC] Using encoding: rec-0ec11a24-c5f1-41d1-9b39-e291ddd940e5-UvCWzS8b0T-XxeAp2dUVgE7T9MP-1582041901723-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.065465450286865
# -------------------------
# [ENC] Using encoding: rec-bc5e0ed9-ebd6-4706-b342-052274a6bed1-3XEnFB5rbr-w8rRtp7WBsjIoLuI-1581597471379-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.0853195190429688
# -------------------------
# [ENC] Using encoding: rec-cacbb992-86eb-4a36-ac72-2cf63509d09a-EAu7qNMqR4-P8Qr0GDGOWvLdSRP-1583747215703-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.511739730834961
# -------------------------
# [ENC] Using encoding: rec-066b0eda-adf4-4149-ba32-d9c1804b1956-VsIOhe3QlF-bqb8fMcj72N5a6U8-1581518679771-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.781833171844482
# -------------------------
# [ENC] Using encoding: rec-eba2d851-d8f3-4c82-9209-02c0d684fa6c-VDT9Lg4esn-hf3TBwegOKmCqkFZ-1581937903596-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.681825876235962
# -------------------------
# [ENC] Using encoding: rec-950f44cd-af65-4c75-b8eb-8b4a6d0ee3d7-KSc30D2Afd-tjWTfKPD7zY3IBXn-1581516913870-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.274288892745972
# -------------------------
# Percentage of people: 87 %
# -------------------------
# [ENC] Using encoding: rec-67fd56ac-f9ec-4c38-9185-1aea0a4b37d0-vtzJWl89bl-d0z5S7SCK9TvbZpn-1580220181216-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 9.959245443344116
# -------------------------
# [ENC] Using encoding: rec-9d8e1949-4c24-44a7-acaf-3bdbf13e07ab-Sj6aFmd8WV-mci9iFKsninDeTjA-1580297654772-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.142479419708252
# -------------------------
# [ENC] Using encoding: rec-02775db9-2e4d-491a-ba5d-43fb715e0c3d-FA8nx738TZ-K7Nm6zOMFD0Q33Pc-1580810763795-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.55193829536438
# -------------------------
# [ENC] Using encoding: rec-3aed0530-d02d-4434-963e-0da4bbd32048-ojcPM2WaFR-6x7S3VieMeYh1lWx-1582882084853-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.6957173347473145
# -------------------------
# [ENC] Using encoding: rec-243687ff-8962-41b6-9807-1a6f588429df-qJlaO2XDOL-9HOqT2kBynhh11Hm-1581513880289-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.080265998840332
# -------------------------
# [ENC] Using encoding: rec-303bfed4-8105-4f2e-8dc1-dbd789afb5d1-Y3HCOHw38i-AHq3aIOQVx5Ivrjt-1581693442102-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.69288444519043
# -------------------------
# [ENC] Using encoding: rec-fbb62c75-fb28-45fa-9df4-1d8b17573394-aMDHDNPhgO-o6zJooCCdnC9Xhls-1581939026962-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 10.052467107772827
# -------------------------
# [ENC] Using encoding: rec-7b46f6fa-79e9-4ee0-9d6e-6abfeec0f790-Ptj0p1vBzy-VPEk83CD8y21Zdui-1582100273441-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.261105298995972
# -------------------------
# Percentage of people: 89 %
# -------------------------
# [ENC] Using encoding: rec-9a645288-af49-4065-a0e2-9d33cc47d506-7E0Xb7COjn-cjUcdCyRK4pRNFaQ-1580216286374-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.9015889167785645
# -------------------------
# [ENC] Using encoding: rec-e6c167a5-5f86-46d0-baf7-d09de7ab4f1d-w1WviRzLG7-LbulamSgcKnoFZG2-1580220405362-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.384589433670044
# -------------------------
# [ENC] Using encoding: rec-1c1bf933-835b-49fd-a178-9ee0fefacc96-mYycDX0R3l-Rbg5Jfnaqje4NlcA-1581442309680-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.3728301525115967
# -------------------------
# [ENC] Using encoding: rec-12a7f92d-f5e1-4f05-b2d1-7593644fb2fa-SwtuF3AUZg-m1Kl7AslMBLAlcXX-1580219780589-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.041501760482788
# -------------------------
# [ENC] Using encoding: rec-b76da48f-42e5-44a2-9bd9-30deb2976913-yjYBbJNluZ-svEfldzeztYdn3dO-1582046238313-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.947170972824097
# -------------------------
# [ENC] Using encoding: rec-dd23a5fa-565a-46bb-b940-195a449f409d-D1NQfXl4D1-6SrEVbNuY3IlleMz-1582652794942-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.9881250858306885
# -------------------------
# [ENC] Using encoding: rec-a72dc325-5bd2-4733-80fb-2d942442f5e1-5esGQBeEt4-Il9BBIMtC6ISTFak-1581084900205-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.1700174808502197
# -------------------------
# Percentage of people: 92 %
# -------------------------
# [ENC] Using encoding: rec-1c3504ca-e652-40c2-8b77-1cd16174919b-oVcNnjQBu9-QlrzRM1VWHAZUKxU-1581443193377-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.7246978282928467
# -------------------------
# [ENC] Using encoding: rec-0d7f6abd-dffb-48f0-8257-b49b7de4aaf1-CQmTlSp0kT-7cZ0YidvOs7n9kKl-1583837876925-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.690517425537109
# -------------------------
# [ENC] Using encoding: rec-94fdbbad-e8b7-4909-bf37-50bf03a3094a-ezFxGi1ZpG-wTXPGfpMrn95iAfD-1582625610311-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 6.041926860809326
# -------------------------
# [ENC] Using encoding: rec-37368802-8d22-47bb-8686-fd5b7240d6fe-njfZngfeiZ-b5gtajBmtQGOXj3E-1579800882047-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 2.301246166229248
# -------------------------
# Percentage of people: 93 %
# -------------------------
# [ENC] Using encoding: rec-920e9140-85df-4c9f-976a-cb1dbf965631-7avfemevEJ-KugjJX1pMJjZl6hH-1579721759218-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.300877332687378
# -------------------------
# [ENC] Using encoding: rec-c4a7e17a-16cd-4400-bbba-8ebd400b0943-CsliHRpehr-OnLa4uF7eNGAKO8J-1579697687299-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.7708985805511475
# -------------------------
# [ENC] Using encoding: rec-0343668a-4d1b-49a9-99fd-5c7b79405bb4-jjUUUmAN5N-szNTIB6uforiSTQ2-1579708266409-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.62463641166687
# -------------------------
# [ENC] Using encoding: rec-7418d0a3-ef33-4aec-8293-c079c3a26718-69C1eJM7Sw-8f63sXQXFY21xaUf-1582218250142-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.011369466781616
# -------------------------
# [ENC] Using encoding: rec-73b1dccc-4ca1-46f5-8c78-b0ff2ecdc1c1-qO5hS01t7u-OA2mq1aB3TcWyCud-1580228870312-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.755183219909668
# -------------------------
# [ENC] Using encoding: rec-95033d2a-c803-4ae1-a24f-876f8a0c6bb9-lkGYs7aPOR-RblE2ogTljpptOBs-1582282031205-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 7.908012866973877
# -------------------------
# [ENC] Using encoding: rec-5a98eb16-f5d4-4115-8b4c-97029e34f64e-pHY5OHDQl5-b2h3T9Gh6KpAyS81-1583847888402-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.2251646518707275
# -------------------------
# Percentage of people: 96 %
# -------------------------
# [ENC] Using encoding: rec-36f8ab43-6595-4e2a-859b-5736c78e429d-5vgPGtjh0v-1V25efjYHlOWGxQV-1584089472422-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 1.4595630168914795
# -------------------------
# [ENC] Using encoding: rec-5bc8f428-4a4c-4984-aa05-58d0d357ff31-HV4sOcVMrr-FgXmq5Zl601G6SZb-1583418117676-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.9271457195281982
# -------------------------
# [ENC] Using encoding: rec-d92650f7-587c-4d80-a691-d726be3b85a2-7AhejWMmUF-XcOKWWgUfJpCzl3k-1582047111293-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.149410009384155
# -------------------------
# [ENC] Using encoding: rec-e9a11d7e-8712-4d61-a3fc-dd86aa26efa9-J8P45cXDdv-66aPvfBTfc7MColE-1584633718138-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 8.500316143035889
# -------------------------
# [ENC] Using encoding: rec-f6291a1b-e71c-4206-b5b5-055ae3f0006d-4ohgQk6sYv-tTDsBWKrtiQ1e6ei-1582882872614-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.621201276779175
# -------------------------
# [ENC] Using encoding: rec-e286ca7d-ecc7-45de-adc8-eb04057d5624-0Yq6f4ml1r-po5DLeRHi8glrR8f-1582218050854-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.9038496017456055
# -------------------------
# [ENC] Using encoding: rec-adca5b9b-4d72-4385-be7e-48720453f2e1-O0VawZ9Ii4-FRoEcPxSFMnP8JIn-1581597654010-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 5.4164042472839355
# -------------------------
# Percentage of people: 98 %
# -------------------------
# [ENC] Using encoding: rec-4afff56a-ad6f-4082-9936-65f375981b65-80H1PINwf7-WkRdbXRyiEzVbJXO-1582300117472-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 4.670935392379761
# -------------------------
# [ENC] Using encoding: rec-76d30a8a-0564-4591-8181-5138e7e6bd6c-lZo47M5cHw-BE0WpOR6t3FE7T7C-1583430559023-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.7161619663238525
# -------------------------
# [ENC] Using encoding: rec-c9da68a1-3082-4479-924a-2500b6b21ba1-vSUgrPD9N1-Ot636fDZFdWlYjjO-1579877696017-video-face.webm
# Already existing folder
# -------------------------
# The comparison last: 3.624269723892212
# -------------------------
# -------------------------
# TEST ENDED
# -------------------------
# This test last: 2126.211336374283

# %% [markdown]
# ## Show results

# %%
base_log = root_path +"logs#10/"
dirs = os.listdir(base_log)
for d in dirs:
  
    folder = base_log + d +'/'
    e = d.split('_')[3]
    f = d.split('_')[4]
    t = d.split('_')[1]
    m = d.split('_')[5]
    if e == '-1':
      e = 'All'
    print("##############")
    print("ENCODINGS",e)
    print("FRAMES",f)
    print("MOD",m)
    print("#############")
    #_,_,_,_ = showStats(folder,d)
    showStatsROC(folder)
# Out:
# ##############
# ENCODINGS 50
# FRAMES 60
# MOD avg
# #############
# Threshold: 0.4 TAR: 0.9635521696915378 FAR 0.031367535344225254
# ##############
# ENCODINGS 50
# FRAMES 60
# MOD min
# #############
# Threshold: 0.4 TAR: 0.9635521696915378 FAR 0.031367535344225254
# ##############
# ENCODINGS 50
# FRAMES 90
# MOD avg
# #############
# Threshold: 0.4 TAR: 0.9646724923444618 FAR 0.024900768578946585
# ##############
# ENCODINGS 50
# FRAMES 90
# MOD min
# #############
# Threshold: 0.4 TAR: 0.9646724923444618 FAR 0.024900768578946585
# ##############
# ENCODINGS 50
# FRAMES 120
# MOD avg
# #############
# Threshold: 0.4 TAR: 0.967286578534618 FAR 0.02226946348135044
# ##############
# ENCODINGS 50
# FRAMES 120
# MOD min
# #############
# Threshold: 0.4 TAR: 0.9672118903577563 FAR 0.02226946348135044
# ##############
# ENCODINGS 50
# FRAMES 89
# MOD avg
# #############
# Threshold: 0.4 TAR: 0.936066920606468 FAR 0.002631305097596147
# ##############
# ENCODINGS All
# FRAMES 90
# MOD avg
# #############
# Threshold: 0.4 TAR: 0.9701247292553589 FAR 0.03996015877027369
