# %% [markdown]
# # Face Recognition #5 TAR
#
# - We are using: DB1-Youtube (half database from A to I)
#
# We want here to generate all the data that will be used later to compute the TAR in the notebook 'FAR&Stats'. The encodings of each person have been already generated. In particular, each person is described by a vector that contains 20 encodings generated from 20 random images taken from a single folder, the test will be performed on the remaining ones.

# %%
import sys
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/PRIM'  # your new root path

sys.path.append(os.path.join(root_path, 'notebooks')) # for importing from utils.py

# !pip install face_recognition
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: face_recognition in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.2)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)

# %%
import argparse
import pickle
import cv2
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os
import dlib
import numpy as np
import matplotlib.pyplot as plt
import time
import random
print(dlib.DLIB_USE_CUDA)
# Out:
# True

# %% [markdown]
# The function below is used to create the encodings, only 20 images of all the one present in the folder are taken in order to generate them.

# %%
def createEncodings(dataset_folder, name, detection='cnn'):

    # grab the paths to the input images in our dataset
    print("[INFO] quantifying faces...")
    imagePathsList = list(paths.list_images(dataset_folder))
    '''
    We're going to take only a limit number of images to create the encodings.
    We'll take a random sample over all the images of a person and in particular
    '''
    num = 20
    if len(imagePathsList )<= 0:
      return

    imagePaths = random.choices(imagePathsList, k = num )

    # initialize the list of known encodings and known names
    knownEncodings = []
    knownNames = []
    # loop over the image paths
    for (i, imagePath) in enumerate(imagePaths):
        # extract the person name from the image path
        #print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
        name = imagePath.split(os.path.sep)[-3]

        # load the input image and convert it from RGB (OpenCV ordering)
        # to dlib ordering (RGB)
        image = cv2.imread(imagePath)
        rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # detect the (x, y)-coordinates of the bounding boxes
        # corresponding to each face in the input image
        boxes = face_recognition.face_locations(rgb,model=detection)

        # compute the facial embedding for the face
        encodings = face_recognition.face_encodings(rgb, boxes)

        # loop over the encodings
        for encoding in encodings:
            # add each encoding + name to our set of known names and
            # encodings
            knownEncodings.append(encoding)
            knownNames.append(name)
    #pdb.set_trace()
    # dump the facial encodings + names to disk
    print("[INFO] serializing encodings..." + name)
    data = {"encodings": knownEncodings, "names": knownNames}
    name = root_path + "/#3_encodings/" + name + '.pkl'
    #print(name)
    f = open(name, "wb")
    f.write(pickle.dumps(data))
    f.close()

# %% [markdown]
# In the function below we compare the list of the 20 encodings of a known person with only one encoding of a different person generated from an **input image** in order to see the result of the algorithm. If the two person are considered the same the name is returned otherwise we have an 'unknown'.
# The decision is based on the **Euclidian distance** $d$ between the encodings,two person are recognized as the same one iff:<br>
# - $d < tolerance$

# %%
def faceRecognition(image, encodings, detection='cnn', show=False,tolerance = 0.6):
    start = time.time()
    # the image is already converted in an rgb format
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # format used by openCV
    data = encodings

    # detect the (x, y)-coordinates of the bounding boxes corresponding
    # to each face in the input image, then compute the facial embeddings
    # for each face
    boxes = face_recognition.face_locations(rgb,model=detection)
    encodings = face_recognition.face_encodings(rgb, boxes)

    # initialize the list of names for each face detected
    names = []

    # loop over the facial embeddings
    for encoding in encodings:
        # attempt to match each face in the input image to our known
        # encodings
        matches = face_recognition.compare_faces(data["encodings"],
            encoding)
        name = "unknown"

        # check to see if we have found a match
        if True in matches:
          # Use the known face with the smallest distance to the new face
          face_distances = face_recognition.face_distance(data["encodings"], encoding)
          best_match_index = np.argmin(face_distances)
          if matches[best_match_index]:
              name = data["names"][best_match_index]

        # update the list of names
        try:
            name = name.split('/')[2]
        except:
            name = name
        names.append(name)

    # loop over the recognized faces
    for ((top, right, bottom, left), name) in zip(boxes, names):
        # draw the predicted face name on the image
        cv2.rectangle(image, (left, top), (right, bottom), (0, 255, 0), 2)
        y = top - 15 if top - 15 > 15 else top + 15
        cv2.putText(image, name, (left, y), cv2.FONT_HERSHEY_SIMPLEX,
            0.75, (0, 255, 0), 2)
    
    
    stop = time.time()
    #print('Time needed:', stop-start, 'sec')
    # show the output image
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    if(show== True):
        print(names)
        plt.imshow(rgb)
        plt.show()
    return names

def imageRead(path, show=True):
    # BGR FORMAT #
    image = cv2.imread(path)
    
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    if(show== True):
        plt.imshow(rgb)
        plt.show()
    return image
    
def encodingsRead(path):
    ## PAY ATTENTION:: You need to create the encoding for you dataset using encode_face.py
    data = pickle.loads(open(path, "rb").read())
    return data

# %%
def faceRecOnFolder(dataset_folder, encodings, correct_person, detection='cnn', min_threshold = 0.75, show=False,tolerance = 0.6):
    imagePaths = list(paths.list_images(dataset_folder))

    analysed_frames = 0
    correct_frames = 0
    negative_frames = 0
    neutrum_frames = 0
    total_frames = len(imagePaths)
    start = time.time()

    if total_frames < 30:
      min_frames = total_frames
    else:
      min_frames = total_frames * 50 / 100
    
    min_threshold = min_threshold
    # grab the paths to the input images in our dataset
    print("[INFO] Recognizing faces...")
    print("[INFO] elements:", total_frames)

    # loop over the image paths
    for (i, imagePath) in enumerate(imagePaths):
        # extract the person name from the image path
        #print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
        image = imageRead(imagePath, show=False)
        person_rec = faceRecognition(image, encodings, detection='cnn', show=False,tolerance = tolerance)
        analysed_frames += 1
        
        if(len(person_rec) >= 1):
            person = person_rec[0]
            if(person == correct_person):
                correct_frames += 1
            else:
                if(person == 'unknown'):
                    neutrum_frames += 1
                else:
                    negative_frames += 1
        else:
            neutrum_frames += 1
        
            
        if( analysed_frames > min_frames and correct_frames/analysed_frames > min_threshold):
            print(correct_person, "Recognized after", analysed_frames, 'with accuracy:', correct_frames/analysed_frames)
            print('Not detected:', neutrum_frames/analysed_frames, ". Wrong recognition:", negative_frames/analysed_frames)
            correct_rate = correct_frames/analysed_frames
            neutrum_rate = neutrum_frames/analysed_frames
            negative_rate = negative_frames/analysed_frames
            end = time.time()
            print('Time:', end-start)
            return True, correct_rate, neutrum_rate, negative_rate
        
    #for ends
    correct_rate = correct_frames/total_frames
    neutrum_rate = neutrum_frames/total_frames
    negative_rate = negative_frames/total_frames
    end = time.time()
    print(correct_person, "Recognized after", analysed_frames, 'with accuracy:', correct_frames/total_frames)
    print('Not detected:', neutrum_frames/total_frames, ". Wrong recognition:", negative_frames/total_frames)
    print('Time:', end-start)
    if(correct_rate > min_threshold - 0.05):
        return True, correct_rate, neutrum_rate, negative_rate
    else:
        return False, correct_rate, neutrum_rate, negative_rate

# %%
def walklevel(some_dir, level=1):
    some_dir = some_dir.rstrip(os.path.sep)
    num_sep = some_dir.count(os.path.sep)
    for root, dirs, files in os.walk(some_dir):
        yield root, dirs, files
        num_sep_this = root.count(os.path.sep)
        if num_sep + level <= num_sep_this:
            del dirs[:]
            

def produceNamesFile(path):
    count = 0
    files = 0
    folders = 0
    f = open("valid.txt", "w")
    #path = "./DB1-Youtube/frame_images_DB"

    for name, dirnames, filenames in walklevel(path):
        if(name != "./DB1-Youtube/frame_images_DB"):
            nfolders = len(dirnames)
            if( nfolders > 1):
                count +=1
                ## we are just using people that have more than one video!
                f.write(name.split("\\")[1] + "\n")
                print(name, dirnames, nfolders)

    print("Number of people useful for the test:", count)
    print("FINE")
    f.close()
    return

# %%
test_path = root_path + "/frame_images_mattia/"
encodings_folder = root_path + "/#3_encodings/"

# %% [markdown]
# The Test compare the encodings of one person with the encodings of himself generated from a different folder in order to compute later the Tar.

# %%
def performTest(min_v=0, max_v=100000, threshold=0.75, log=False,tolerance = 0.6):
    print("-------------------------")
    print("TEST STARTED")
    print("-------------------------")
    
    count = 0
    n_test = 0
    n_correct = 0
  
    valid_persons = os.listdir(test_path)

    log_folder_base = 'test_' + str(threshold) + '_' + str(tolerance) + '/'


    if( log == True):
      log_folder = log_folder_base + 'T/'
      try:
          #os.mkdir(root_path + '/logs#5/' + log_folder_base)
          os.mkdir(root_path + '/logs#5/' + log_folder)
      except FileExistsError:
          print('Already existing folder')
      logfile = open(root_path + '/logs#5/' + log_folder + "log" + str(min_v) + "-" + str(max_v) + ".txt", "w")
        
    for person in valid_persons:
        count = count +1
        if(count < min_v):
            continue
        if(count > max_v):
            break

        #person = person[0:len(person)-1]
        test_folder = test_path + person
        #test_folder = test_folder.replace("/", "\\")
        print(test_folder)
        # create the enconding related to first folder of the person
        folder_list = os.listdir(test_folder)
        first_n_folder = folder_list[0]
        train_folder = test_folder + "/" + first_n_folder
        res = os.path.exists(encodings_folder + person + ".pkl")
        if(res == False):
            #print("Qualcosa è andato storto!!")
            print("Creation encodings on",train_folder)
            #muori = 1/0
            createEncodings(train_folder, person)
        
        # test the encodings of testset
        train_flag = 0
        for n_folder in folder_list:
            if( train_flag == 0):
                train_flag = 1
                continue
            
            n_test += 1
            folder = test_folder + "/" + n_folder
            encoding = encodingsRead(encodings_folder + person + ".pkl")
            v, a, b, c = faceRecOnFolder(folder, encoding, person, min_threshold=threshold, show=True,tolerance = tolerance)
            if(log== True):
                line = person + " " + n_folder + " " + str(v) + " " + str(a) + " " + str(b) + " " + str(c) + "\n"
                logfile.write(line)

            if( v == True):
                n_correct += 1
    
    if(log == True):
        logfile.close()
    print("-------------------------")
    print("TEST ENDED")
    print("-------------------------")
    print('Accuracy on videos tested:', n_correct/n_test)
    return

# %% [markdown]
# The aim of our experiment is to compare the encoding of each person multiple times, and every time with a different value of tolerance in order to make at each iteration a more strict comparison.

# %%
tol_values = [ 0.6, 0.5, 0.4, 0.3, 0.2, 0.1 ]
thr = 0.70

for tol in tol_values:
        print('********')
        print('TOLERANCE', tol)
        print('********')
        performTest(min_v=0, max_v = 200, log=True, threshold= thr, tolerance= tol)
# Out:
# Streaming output truncated to the last 5000 lines.
# [INFO] Recognizing faces...
# [INFO] elements: 53
# Jaime_Pressly Recognized after 27 with accuracy: 0.9629629629629629
# Not detected: 0.037037037037037035 . Wrong recognition: 0.0
# Time: 0.9412577152252197
# [INFO] Recognizing faces...
# [INFO] elements: 62
# Jaime_Pressly Recognized after 32 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8296246528625488
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jack_Valenti
# [INFO] Recognizing faces...
# [INFO] elements: 2041
# Jack_Valenti Recognized after 1021 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 27.3446102142334
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Jack_Valenti Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0195739269256592
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jackie_Chan
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Jackie_Chan Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0443646907806396
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jackie_Sherrill
# [INFO] Recognizing faces...
# [INFO] elements: 385
# Jackie_Sherrill Recognized after 193 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 5.107814311981201
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Jackie_Sherrill Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3026807308197021
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Caan
# [INFO] Recognizing faces...
# [INFO] elements: 125
# James_Caan Recognized after 63 with accuracy: 0.9365079365079365
# Not detected: 0.06349206349206349 . Wrong recognition: 0.0
# Time: 1.8185055255889893
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Carville
# [INFO] Recognizing faces...
# [INFO] elements: 206
# James_Carville Recognized after 104 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.7111589908599854
# [INFO] Recognizing faces...
# [INFO] elements: 297
# James_Carville Recognized after 297 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 7.933455228805542
# [INFO] Recognizing faces...
# [INFO] elements: 57
# James_Carville Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7560017108917236
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Coburn
# [INFO] Recognizing faces...
# [INFO] elements: 86
# James_Coburn Recognized after 44 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.8008148670196533
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jalen_Rose
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Jalen_Rose Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6654934883117676
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jake_Plummer
# [INFO] Recognizing faces...
# [INFO] elements: 89
# Jake_Plummer Recognized after 45 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1891484260559082
# [INFO] Recognizing faces...
# [INFO] elements: 120
# Jake_Plummer Recognized after 61 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6146931648254395
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Baker
# [INFO] Recognizing faces...
# [INFO] elements: 915
# James_Baker Recognized after 458 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 19.517618656158447
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Comey
# [INFO] Recognizing faces...
# [INFO] elements: 62
# James_Comey Recognized after 32 with accuracy: 0.9375
# Not detected: 0.0625 . Wrong recognition: 0.0
# Time: 1.6322789192199707
# [INFO] Recognizing faces...
# [INFO] elements: 697
# James_Comey Recognized after 349 with accuracy: 0.9799426934097422
# Not detected: 0.02005730659025788 . Wrong recognition: 0.0
# Time: 12.41467571258545
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Cunningham
# [INFO] Recognizing faces...
# [INFO] elements: 57
# James_Cunningham Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8561255931854248
# [INFO] Recognizing faces...
# [INFO] elements: 285
# James_Cunningham Recognized after 143 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.8242201805114746
# [INFO] Recognizing faces...
# [INFO] elements: 97
# James_Cunningham Recognized after 49 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2833442687988281
# [INFO] Recognizing faces...
# [INFO] elements: 75
# James_Cunningham Recognized after 38 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9822807312011719
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Brazelton
# [INFO] Recognizing faces...
# [INFO] elements: 101
# James_Brazelton Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.960700511932373
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Gandolfini
# [INFO] Recognizing faces...
# [INFO] elements: 89
# James_Gandolfini Recognized after 89 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 3.6655983924865723
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Murdoch
# [INFO] Recognizing faces...
# [INFO] elements: 52
# James_Murdoch Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1417622566223145
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Sensenbrenner
# [INFO] Recognizing faces...
# [INFO] elements: 1837
# James_Sensenbrenner Recognized after 919 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 24.743042707443237
# [INFO] Recognizing faces...
# [INFO] elements: 62
# James_Sensenbrenner Recognized after 41 with accuracy: 0.7073170731707317
# Not detected: 0.2926829268292683 . Wrong recognition: 0.0
# Time: 2.297058343887329
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Meeks
# [INFO] Recognizing faces...
# [INFO] elements: 493
# James_Meeks Recognized after 247 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 6.340406894683838
# [INFO] Recognizing faces...
# [INFO] elements: 53
# James_Meeks Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.5166547298431396
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Hoffa
# [INFO] Recognizing faces...
# [INFO] elements: 642
# James_Hoffa Recognized after 322 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 7.509118556976318
# [INFO] Recognizing faces...
# [INFO] elements: 143
# James_Hoffa Recognized after 72 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.003939628601074
# [INFO] Recognizing faces...
# [INFO] elements: 98
# James_Hoffa Recognized after 50 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.309746503829956
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Kirtley
# [INFO] Recognizing faces...
# [INFO] elements: 201
# James_Kirtley Recognized after 101 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.6544880867004395
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_McPherson
# [INFO] Recognizing faces...
# [INFO] elements: 406
# James_McPherson Recognized after 204 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 5.335183382034302
# [INFO] Recognizing faces...
# [INFO] elements: 208
# James_McPherson Recognized after 105 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.7178781032562256
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Wattana
# [INFO] Recognizing faces...
# [INFO] elements: 129
# James_Wattana Recognized after 65 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6757802963256836
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Traficant
# [INFO] Recognizing faces...
# [INFO] elements: 117
# James_Traficant Recognized after 59 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.6953535079956055
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Lockhart
# [INFO] Recognizing faces...
# [INFO] elements: 58
# James_Lockhart Recognized after 30 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0328190326690674
# [INFO] Recognizing faces...
# [INFO] elements: 1853
# James_Lockhart Recognized after 927 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 23.389193058013916
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_McGreevey
# [INFO] Recognizing faces...
# [INFO] elements: 57
# James_McGreevey Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0686297416687012
# [INFO] Recognizing faces...
# [INFO] elements: 89
# James_McGreevey Recognized after 45 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.8097941875457764
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Janusz_Kaminski
# [INFO] Recognizing faces...
# [INFO] elements: 69
# Janusz_Kaminski Recognized after 35 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0633611679077148
# [INFO] Recognizing faces...
# [INFO] elements: 98
# Janusz_Kaminski Recognized after 50 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1475460529327393
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jane_Rooney
# [INFO] Recognizing faces...
# [INFO] elements: 221
# Jane_Rooney Recognized after 111 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.9191207885742188
# [INFO] Recognizing faces...
# [INFO] elements: 517
# Jane_Rooney Recognized after 259 with accuracy: 0.9922779922779923
# Not detected: 0.007722007722007722 . Wrong recognition: 0.0
# Time: 11.924265384674072
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jane_Krakowski
# [INFO] Recognizing faces...
# [INFO] elements: 149
# Jane_Krakowski Recognized after 75 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.974240779876709
# [INFO] Recognizing faces...
# [INFO] elements: 81
# Jane_Krakowski Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.083287000656128
# [INFO] Recognizing faces...
# [INFO] elements: 81
# Jane_Krakowski Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4821937084197998
# [INFO] Recognizing faces...
# [INFO] elements: 53
# Jane_Krakowski Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7363932132720947
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jane_Pauley
# [INFO] Recognizing faces...
# [INFO] elements: 157
# Jane_Pauley Recognized after 157 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 6.69432806968689
# [INFO] Recognizing faces...
# [INFO] elements: 278
# Jane_Pauley Recognized after 278 with accuracy: 0.07913669064748201
# Not detected: 0.920863309352518 . Wrong recognition: 0.0
# Time: 11.758152723312378
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Janis_Ruth_Coulter
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Janis_Ruth_Coulter Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8123276233673096
# [INFO] Recognizing faces...
# [INFO] elements: 62
# Janis_Ruth_Coulter Recognized after 32 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3591387271881104
# [INFO] Recognizing faces...
# [INFO] elements: 288
# Janis_Ruth_Coulter Recognized after 145 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.8396832942962646
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jane_Fonda
# [INFO] Recognizing faces...
# [INFO] elements: 93
# Jane_Fonda Recognized after 47 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.9635100364685059
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/James_Wolfensohn
# [INFO] Recognizing faces...
# [INFO] elements: 70
# James_Wolfensohn Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2994229793548584
# [INFO] Recognizing faces...
# [INFO] elements: 241
# James_Wolfensohn Recognized after 121 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.1624202728271484
# [INFO] Recognizing faces...
# [INFO] elements: 749
# James_Wolfensohn Recognized after 375 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 14.285334825515747
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jamie_Lee_Curtis
# [INFO] Recognizing faces...
# [INFO] elements: 77
# Jamie_Lee_Curtis Recognized after 39 with accuracy: 0.7948717948717948
# Not detected: 0.20512820512820512 . Wrong recognition: 0.0
# Time: 1.0246453285217285
# [INFO] Recognizing faces...
# [INFO] elements: 145
# Jamie_Lee_Curtis Recognized after 145 with accuracy: 0.4482758620689655
# Not detected: 0.5517241379310345 . Wrong recognition: 0.0
# Time: 3.642803192138672
# [INFO] Recognizing faces...
# [INFO] elements: 145
# Jamie_Lee_Curtis Recognized after 145 with accuracy: 0.5379310344827586
# Not detected: 0.46206896551724136 . Wrong recognition: 0.0
# Time: 3.7190518379211426
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jamie_Dimon
# [INFO] Recognizing faces...
# [INFO] elements: 95
# Jamie_Dimon Recognized after 95 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 3.9908852577209473
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jane_Kaczmarek
# [INFO] Recognizing faces...
# [INFO] elements: 63
# Jane_Kaczmarek Recognized after 32 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.357105016708374
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Karen_Lynn_Gorney
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Karen_Lynn_Gorney Recognized after 49 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 1.709608793258667
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jan_Bjoerklund
# [INFO] Recognizing faces...
# [INFO] elements: 1100
# Jan_Bjoerklund Recognized after 551 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 14.747633695602417
# [INFO] Recognizing faces...
# [INFO] elements: 109
# Jan_Bjoerklund Recognized after 109 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 3.7934303283691406
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jan_Peter_Balkenende
# [INFO] Recognizing faces...
# [INFO] elements: 119
# Jan_Peter_Balkenende Recognized after 60 with accuracy: 0.95
# Not detected: 0.05 . Wrong recognition: 0.0
# Time: 2.546717882156372
# [INFO] Recognizing faces...
# [INFO] elements: 53
# Jan_Peter_Balkenende Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8479490280151367
# [INFO] Recognizing faces...
# [INFO] elements: 113
# Jan_Peter_Balkenende Recognized after 57 with accuracy: 0.9473684210526315
# Not detected: 0.05263157894736842 . Wrong recognition: 0.0
# Time: 2.403169870376587
# [INFO] Recognizing faces...
# [INFO] elements: 82
# Jan_Peter_Balkenende Recognized after 42 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.345665454864502
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Karin_Viard
# [INFO] Recognizing faces...
# [INFO] elements: 85
# Karin_Viard Recognized after 47 with accuracy: 0.7021276595744681
# Not detected: 0.2978723404255319 . Wrong recognition: 0.0
# Time: 1.6627752780914307
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/JK_Rowling
# [INFO] Recognizing faces...
# [INFO] elements: 73
# JK_Rowling Recognized after 73 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 2.308642625808716
# [INFO] Recognizing faces...
# [INFO] elements: 189
# JK_Rowling Recognized after 95 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.6581504344940186
# [INFO] Recognizing faces...
# [INFO] elements: 51
# JK_Rowling Recognized after 51 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 1.335988998413086
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kate_Capshaw
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Kate_Capshaw Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0678722858428955
# [INFO] Recognizing faces...
# [INFO] elements: 57
# Kate_Capshaw Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7648670673370361
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jan_Ullrich
# [INFO] Recognizing faces...
# [INFO] elements: 117
# Jan_Ullrich Recognized after 117 with accuracy: 0.358974358974359
# Not detected: 0.6410256410256411 . Wrong recognition: 0.0
# Time: 3.607893705368042
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Katalin_Kollat
# [INFO] Recognizing faces...
# [INFO] elements: 57
# Katalin_Kollat Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2011547088623047
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jason_Biggs
# [INFO] Recognizing faces...
# [INFO] elements: 131
# Jason_Biggs Recognized after 66 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6966402530670166
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Jason_Biggs Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9578382968902588
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Jaouad_Gharib
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Jaouad_Gharib Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9684832096099854
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kathryn_Morris
# [INFO] Recognizing faces...
# [INFO] elements: 149
# Kathryn_Morris Recognized after 75 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.9719493389129639
# [INFO] Recognizing faces...
# [INFO] elements: 55
# Kathryn_Morris Recognized after 28 with accuracy: 0.9642857142857143
# Not detected: 0.03571428571428571 . Wrong recognition: 0.0
# Time: 1.0540721416473389
# [INFO] Recognizing faces...
# [INFO] elements: 393
# Kathryn_Morris Recognized after 197 with accuracy: 0.8071065989847716
# Not detected: 0.19289340101522842 . Wrong recognition: 0.0
# Time: 5.197483777999878
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Keira_Knightley
# [INFO] Recognizing faces...
# [INFO] elements: 57
# Keira_Knightley Recognized after 29 with accuracy: 0.7931034482758621
# Not detected: 0.20689655172413793 . Wrong recognition: 0.0
# Time: 1.2099430561065674
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Katja_Riemann
# [INFO] Recognizing faces...
# [INFO] elements: 102
# Katja_Riemann Recognized after 52 with accuracy: 0.9807692307692307
# Not detected: 0.019230769230769232 . Wrong recognition: 0.0
# Time: 2.1810355186462402
# [INFO] Recognizing faces...
# [INFO] elements: 105
# Katja_Riemann Recognized after 53 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.9194462299346924
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kate_Winslet
# [INFO] Recognizing faces...
# [INFO] elements: 580
# Kate_Winslet Recognized after 291 with accuracy: 0.9553264604810997
# Not detected: 0.044673539518900345 . Wrong recognition: 0.0
# Time: 7.42724084854126
# [INFO] Recognizing faces...
# [INFO] elements: 1051
# Kate_Winslet Recognized after 526 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 22.370612144470215
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Keith_Olbermann
# [INFO] Recognizing faces...
# [INFO] elements: 785
# Keith_Olbermann Recognized after 393 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 10.345693349838257
# [INFO] Recognizing faces...
# [INFO] elements: 54
# Keith_Olbermann Recognized after 54 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 1.0393998622894287
# [INFO] Recognizing faces...
# [INFO] elements: 133
# Keith_Olbermann Recognized after 67 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.206751823425293
# [INFO] Recognizing faces...
# [INFO] elements: 497
# Keith_Olbermann Recognized after 249 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 7.186820030212402
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Katharine_Hepburn
# [INFO] Recognizing faces...
# [INFO] elements: 101
# Katharine_Hepburn Recognized after 51 with accuracy: 0.803921568627451
# Not detected: 0.19607843137254902 . Wrong recognition: 0.0
# Time: 1.3770923614501953
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Katharine_Hepburn Recognized after 49 with accuracy: 0.4897959183673469
# Not detected: 0.5102040816326531 . Wrong recognition: 0.0
# Time: 1.3031272888183594
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kenneth_Reichert
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Kenneth_Reichert Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.889976978302002
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Tom_Izzo
# [INFO] Recognizing faces...
# [INFO] elements: 97
# Tom_Izzo Recognized after 49 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2656309604644775
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kevin_Borseth
# [INFO] Recognizing faces...
# [INFO] elements: 83
# Kevin_Borseth Recognized after 83 with accuracy: 0.03614457831325301
# Not detected: 0.963855421686747 . Wrong recognition: 0.0
# Time: 1.6061677932739258
# [INFO] Recognizing faces...
# [INFO] elements: 100
# Kevin_Borseth Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3115262985229492
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kenneth_Branagh
# [INFO] Recognizing faces...
# [INFO] elements: 66
# Kenneth_Branagh Recognized after 66 with accuracy: 0.18181818181818182
# Not detected: 0.8181818181818182 . Wrong recognition: 0.0
# Time: 4.783522129058838
# [INFO] Recognizing faces...
# [INFO] elements: 100
# Kenneth_Branagh Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6287555694580078
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kemal_Dervis
# [INFO] Recognizing faces...
# [INFO] elements: 100
# Kemal_Dervis Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.1330325603485107
# [INFO] Recognizing faces...
# [INFO] elements: 53
# Kemal_Dervis Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7254188060760498
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Ken_Watanabe
# [INFO] Recognizing faces...
# [INFO] elements: 81
# Ken_Watanabe Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.088066577911377
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kelsey_Grammer
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Kelsey_Grammer Recognized after 25 with accuracy: 0.92
# Not detected: 0.08 . Wrong recognition: 0.0
# Time: 0.6682248115539551
# [INFO] Recognizing faces...
# [INFO] elements: 89
# Kelsey_Grammer Recognized after 45 with accuracy: 0.7777777777777778
# Not detected: 0.2222222222222222 . Wrong recognition: 0.0
# Time: 1.1769599914550781
# [INFO] Recognizing faces...
# [INFO] elements: 100
# Kelsey_Grammer Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6488170623779297
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kevin_Satterfield
# [INFO] Recognizing faces...
# [INFO] elements: 83
# Kevin_Satterfield Recognized after 42 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1092216968536377
# [INFO] Recognizing faces...
# [INFO] elements: 100
# Kevin_Satterfield Recognized after 51 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6839845180511475
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kenneth_Carlsen
# [INFO] Recognizing faces...
# [INFO] elements: 72
# Kenneth_Carlsen Recognized after 37 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3367693424224854
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kieran_Culkin
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kieran_Culkin Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.042802333831787
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kieran_Culkin Recognized after 46 with accuracy: 0.782608695652174
# Not detected: 0.21739130434782608 . Wrong recognition: 0.0
# Time: 1.9484074115753174
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kit_Bond
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kit_Bond Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2087526321411133
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kit_Bond Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2374587059020996
# [INFO] Recognizing faces...
# [INFO] elements: 81
# Kit_Bond Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4819669723510742
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kirk_Ferentz
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kirk_Ferentz Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2404887676239014
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kirk_Ferentz Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2156908512115479
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Kirk_Ferentz Recognized after 61 with accuracy: 0.36065573770491804
# Not detected: 0.639344262295082 . Wrong recognition: 0.0
# Time: 4.228193283081055
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kirk_Ferentz Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2096216678619385
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kim_Cattrall
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kim_Cattrall Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.838517189025879
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kostya_Tszyu
# [INFO] Recognizing faces...
# [INFO] elements: 69
# Kostya_Tszyu Recognized after 35 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.5114383697509766
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kevin_Spacey
# [INFO] Recognizing faces...
# [INFO] elements: 77
# Kevin_Spacey Recognized after 39 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.020317554473877
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kevin_Spacey Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2026121616363525
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Kevin_Spacey Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3543169498443604
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kevin_Spacey Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4820237159729004
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kevin_Spacey Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.9208002090454102
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/King_Abdullah_II
# [INFO] Recognizing faces...
# [INFO] elements: 90
# King_Abdullah_II Recognized after 90 with accuracy: 0.1
# Not detected: 0.9 . Wrong recognition: 0.0
# Time: 6.538955926895142
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kim_Gandy
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kim_Gandy Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1902687549591064
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kim_Gandy Recognized after 46 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2097663879394531
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Kim_Gandy Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2968709468841553
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kim_Gandy Recognized after 46 with accuracy: 0.9565217391304348
# Not detected: 0.043478260869565216 . Wrong recognition: 0.0
# Time: 1.204549789428711
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kirsten_Dunst
# [INFO] Recognizing faces...
# [INFO] elements: 74
# Kirsten_Dunst Recognized after 44 with accuracy: 0.7045454545454546
# Not detected: 0.29545454545454547 . Wrong recognition: 0.0
# Time: 1.1527302265167236
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kirsten_Dunst Recognized after 90 with accuracy: 0.6333333333333333
# Not detected: 0.36666666666666664 . Wrong recognition: 0.0
# Time: 2.139798641204834
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Kirsten_Dunst Recognized after 49 with accuracy: 0.12244897959183673
# Not detected: 0.8775510204081632 . Wrong recognition: 0.0
# Time: 1.8497340679168701
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kofi_Annan
# [INFO] Recognizing faces...
# [INFO] elements: 90
# Kofi_Annan Recognized after 46 with accuracy: 0.717391304347826
# Not detected: 0.2826086956521739 . Wrong recognition: 0.0
# Time: 2.885232448577881
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lance_Bass
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Lance_Bass Recognized after 61 with accuracy: 0.5409836065573771
# Not detected: 0.45901639344262296 . Wrong recognition: 0.0
# Time: 2.1622154712677
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Brown
# [INFO] Recognizing faces...
# [INFO] elements: 66
# Larry_Brown Recognized after 34 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.88987135887146
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kweisi_Mfume
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kweisi_Mfume Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0742294788360596
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kweisi_Mfume Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0601780414581299
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kweisi_Mfume Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3889541625976562
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Krishna_Bhadur_Mahara
# [INFO] Recognizing faces...
# [INFO] elements: 51
# Krishna_Bhadur_Mahara Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6979095935821533
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Krishna_Bhadur_Mahara Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1505215167999268
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Krishna_Bhadur_Mahara Recognized after 41 with accuracy: 0.9512195121951219
# Not detected: 0.04878048780487805 . Wrong recognition: 0.0
# Time: 1.0801761150360107
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Krishna_Bhadur_Mahara Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9029386043548584
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kyle_Shewfelt
# [INFO] Recognizing faces...
# [INFO] elements: 57
# Kyle_Shewfelt Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2063255310058594
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kyle_Shewfelt Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.7306146621704102
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kyle_Shewfelt Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1666982173919678
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kristin_Chenoweth
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristin_Chenoweth Recognized after 41 with accuracy: 0.7804878048780488
# Not detected: 0.21951219512195122 . Wrong recognition: 0.0
# Time: 1.619955062866211
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristin_Chenoweth Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1162195205688477
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristin_Chenoweth Recognized after 41 with accuracy: 0.9024390243902439
# Not detected: 0.0975609756097561 . Wrong recognition: 0.0
# Time: 1.0851349830627441
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kristin_Scott
# [INFO] Recognizing faces...
# [INFO] elements: 52
# Kristin_Scott Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.183929204940796
# [INFO] Recognizing faces...
# [INFO] elements: 55
# Kristin_Scott Recognized after 55 with accuracy: 0.6181818181818182
# Not detected: 0.38181818181818183 . Wrong recognition: 0.0
# Time: 2.324457883834839
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kurt_Warner
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Kurt_Warner Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1055655479431152
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Kurt_Warner Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9269957542419434
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kristen_Breitweiser
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristen_Breitweiser Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.661388635635376
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristen_Breitweiser Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.7682785987854004
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristen_Breitweiser Recognized after 41 with accuracy: 0.926829268292683
# Not detected: 0.07317073170731707 . Wrong recognition: 0.0
# Time: 1.420853853225708
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Kristy_Curry
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristy_Curry Recognized after 41 with accuracy: 0.926829268292683
# Not detected: 0.07317073170731707 . Wrong recognition: 0.0
# Time: 1.1963651180267334
# [INFO] Recognizing faces...
# [INFO] elements: 80
# Kristy_Curry Recognized after 41 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.5342857837677
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Lucchino
# [INFO] Recognizing faces...
# [INFO] elements: 57
# Larry_Lucchino Recognized after 29 with accuracy: 0.8620689655172413
# Not detected: 0.13793103448275862 . Wrong recognition: 0.0
# Time: 1.2083513736724854
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Bozzo
# [INFO] Recognizing faces...
# [INFO] elements: 53
# Laura_Bozzo Recognized after 27 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7121627330780029
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Bozzo Recognized after 36 with accuracy: 0.8055555555555556
# Not detected: 0.19444444444444445 . Wrong recognition: 0.0
# Time: 1.488560676574707
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Bush
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Bush Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9685428142547607
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Bush Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.2853469848632812
# [INFO] Recognizing faces...
# [INFO] elements: 48
# Laura_Bush Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.2444512844085693
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Flessel
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Flessel Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1494696140289307
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Nichols
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Larry_Nichols Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.5390653610229492
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Ellison
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Larry_Ellison Recognized after 36 with accuracy: 0.8333333333333334
# Not detected: 0.16666666666666666 . Wrong recognition: 0.0
# Time: 0.6960408687591553
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Wilmore
# [INFO] Recognizing faces...
# [INFO] elements: 69
# Larry_Wilmore Recognized after 35 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.374337911605835
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Larry_Wilmore Recognized after 50 with accuracy: 0.44
# Not detected: 0.56 . Wrong recognition: 0.0
# Time: 1.2405052185058594
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Elena_Harring
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Elena_Harring Recognized after 36 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.363736867904663
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Elena_Harring Recognized after 36 with accuracy: 0.8888888888888888
# Not detected: 0.1111111111111111 . Wrong recognition: 0.0
# Time: 0.9521043300628662
# [INFO] Recognizing faces...
# [INFO] elements: 70
# Laura_Elena_Harring Recognized after 36 with accuracy: 0.9722222222222222
# Not detected: 0.027777777777777776 . Wrong recognition: 0.0
# Time: 0.9349427223205566
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Linney
# [INFO] Recognizing faces...
# [INFO] elements: 60
# Laura_Linney Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3156161308288574
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Larry_Flynt
# [INFO] Recognizing faces...
# [INFO] elements: 67
# Larry_Flynt Recognized after 34 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8934121131896973
# [INFO] Recognizing faces...
# [INFO] elements: 69
# Larry_Flynt Recognized after 35 with accuracy: 0.9714285714285714
# Not detected: 0.02857142857142857 . Wrong recognition: 0.0
# Time: 1.442368745803833
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laura_Pausini
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laura_Pausini Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8171520233154297
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lauren_Hutton
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lauren_Hutton Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0762810707092285
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lauren_Hutton Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6780695915222168
# [INFO] Recognizing faces...
# [INFO] elements: 56
# Lauren_Hutton Recognized after 29 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7695047855377197
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lauren_Hutton Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0931029319763184
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lauren_Hutton Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0068812370300293
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laurie_Laychak
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laurie_Laychak Recognized after 50 with accuracy: 0.32
# Not detected: 0.68 . Wrong recognition: 0.0
# Time: 1.283005952835083
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laurie_Laychak Recognized after 50 with accuracy: 0.66
# Not detected: 0.34 . Wrong recognition: 0.0
# Time: 1.3042991161346436
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laurent_Woulzy
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Laurent_Woulzy Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0245046615600586
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laurence_Tribe
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laurence_Tribe Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7020306587219238
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lee_Byung-woong
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lee_Byung-woong Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6917703151702881
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lee_Baca
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lee_Baca Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7372493743896484
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lee_Baca Recognized after 26 with accuracy: 0.7307692307692307
# Not detected: 0.2692307692307692 . Wrong recognition: 0.0
# Time: 0.6793532371520996
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lee_Baca Recognized after 50 with accuracy: 0.34
# Not detected: 0.66 . Wrong recognition: 0.0
# Time: 3.41155743598938
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leland_Chapman
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Leland_Chapman Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6850149631500244
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lena_Katina
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lena_Katina Recognized after 50 with accuracy: 0.5
# Not detected: 0.5 . Wrong recognition: 0.0
# Time: 2.0550312995910645
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Laurence_Fishburne
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laurence_Fishburne Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.690330982208252
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Laurence_Fishburne Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0340077877044678
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leonid_Kuchma
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Leonid_Kuchma Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6414988040924072
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leticia_Van_de_Putte
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Leticia_Van_de_Putte Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.1056268215179443
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Leticia_Van_de_Putte Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6327881813049316
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lenny_Wilkens
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lenny_Wilkens Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7147729396820068
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leszek_Miller
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Leszek_Miller Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8955790996551514
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Leszek_Miller Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6898097991943359
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leuris_Pupo
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Leuris_Pupo Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5578818321228027
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Leuris_Pupo Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5491704940795898
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Leuris_Pupo Recognized after 40 with accuracy: 0.225
# Not detected: 0.775 . Wrong recognition: 0.0
# Time: 1.9020733833312988
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lesia_Burlak
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lesia_Burlak Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7473523616790771
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lesia_Burlak Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7556142807006836
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lester_Holt
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lester_Holt Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8430624008178711
# [INFO] Recognizing faces...
# [INFO] elements: 50
# Lester_Holt Recognized after 26 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0194675922393799
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lena_Olin
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lena_Olin Recognized after 21 with accuracy: 0.7619047619047619
# Not detected: 0.23809523809523808 . Wrong recognition: 0.0
# Time: 0.7458686828613281
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Leticia_Dolera
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Leticia_Dolera Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5546116828918457
# [INFO] Recognizing faces...
# [INFO] elements: 44
# Leticia_Dolera Recognized after 23 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4184672832489014
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lene_Espersen
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lene_Espersen Recognized after 21 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8674366474151611
# [INFO] Recognizing faces...
# [INFO] elements: 40
# Lene_Espersen Recognized after 37 with accuracy: 0.7027027027027027
# Not detected: 0.2972972972972973 . Wrong recognition: 0.0
# Time: 0.933361291885376
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lincoln_Chafee
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lincoln_Chafee Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.42528700828552246
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lincoln_Chafee Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.43711018562316895
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Mason
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Mason Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5803380012512207
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Lingle
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Lingle Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.429882287979126
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Lingle Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6370878219604492
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Li_Zhaoxing
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Li_Zhaoxing Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6207730770111084
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Li_Zhaoxing Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.4815523624420166
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lin_Yung_Hsi
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lin_Yung_Hsi Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6701502799987793
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Liane_Janda
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Liane_Janda Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6817283630371094
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Dano
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 0.8125
# Not detected: 0.1875 . Wrong recognition: 0.0
# Time: 0.7499737739562988
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6673123836517334
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6812889575958252
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.681506872177124
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lewis_Booth
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lewis_Booth Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# ...
# Time: 0.579016923904419
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Lingle
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Lingle Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.4352729320526123
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Lingle Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6428256034851074
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Li_Zhaoxing
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Li_Zhaoxing Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6318926811218262
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Li_Zhaoxing Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.48444151878356934
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lin_Yung_Hsi
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lin_Yung_Hsi Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6779451370239258
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Liane_Janda
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Liane_Janda Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6834759712219238
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Dano
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 0.8125
# Not detected: 0.1875 . Wrong recognition: 0.0
# Time: 0.7521052360534668
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6798031330108643
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6943018436431885
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Dano Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6944823265075684
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lewis_Booth
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lewis_Booth Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5825080871582031
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lily_Tomlin
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Lily_Tomlin Recognized after 30 with accuracy: 0.6666666666666666
# Not detected: 0.3333333333333333 . Wrong recognition: 0.0
# Time: 0.7533566951751709
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Franklin
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Franklin Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6979620456695557
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Franklin Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.681462287902832
# [INFO] Recognizing faces...
# [INFO] elements: 30
# Linda_Franklin Recognized after 16 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6599507331848145
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Liu_Ye
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Liu_Ye Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.528052568435669
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Liu_Ye Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.806276798248291
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Liu_Ye Recognized after 20 with accuracy: 0.8
# Not detected: 0.2 . Wrong recognition: 0.0
# Time: 0.5181035995483398
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Liu_Ye Recognized after 20 with accuracy: 0.8
# Not detected: 0.2 . Wrong recognition: 0.0
# Time: 0.5351693630218506
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lisa_Marie_Presley
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Marie_Presley Recognized after 20 with accuracy: 0.95
# Not detected: 0.05 . Wrong recognition: 0.0
# Time: 0.5306186676025391
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Marie_Presley Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5322532653808594
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Marie_Presley Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5262224674224854
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Liu_Mingkang
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Liu_Mingkang Recognized after 20 with accuracy: 0.05
# Not detected: 0.95 . Wrong recognition: 0.0
# Time: 0.8542943000793457
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linda_Sanchez
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Linda_Sanchez Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7640445232391357
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Linda_Sanchez Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.8705439567565918
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Linda_Sanchez Recognized after 20 with accuracy: 0.85
# Not detected: 0.15 . Wrong recognition: 0.0
# Time: 0.583916425704956
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lisa_Ling
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Ling Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.7203164100646973
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Ling Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.839815616607666
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lindsey_Graham
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lindsey_Graham Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.5350754261016846
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lindsey_Graham Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4098327159881592
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lindsey_Graham Recognized after 20 with accuracy: 0.45
# Not detected: 0.55 . Wrong recognition: 0.0
# Time: 0.5555658340454102
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Linus_Roache
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Linus_Roache Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4337201118469238
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lino_Oviedo
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lino_Oviedo Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.38674187660217285
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lino_Oviedo Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.39054346084594727
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lionel_Richie
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lionel_Richie Recognized after 20 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 1.4360675811767578
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lionel_Richie Recognized after 20 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.5142629146575928
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lisa_Leslie
# [INFO] Recognizing faces...
# [INFO] elements: 20
# Lisa_Leslie Recognized after 20 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.6979434490203857
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lorraine_Bracco
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lorraine_Bracco Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.2656123638153076
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Loretta_Lynn_Harper
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Loretta_Lynn_Harper Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.4238278865814209
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Loretta_Lynn_Harper Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.3801259994506836
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Loretta_Lynn_Harper Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.4187922477722168
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Liv_Tyler
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Liv_Tyler Recognized after 10 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.3354330062866211
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lou_Lang
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lou_Lang Recognized after 10 with accuracy: 0.9
# Not detected: 0.1 . Wrong recognition: 0.0
# Time: 0.2936859130859375
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lou_Lang Recognized after 10 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.19187450408935547
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lou_Lang Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.28900814056396484
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Louis_Van_Gaal
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Louis_Van_Gaal Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.42737865447998047
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Louis_Van_Gaal Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.2670567035675049
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Luciano_Pavarotti
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Luciano_Pavarotti Recognized after 10 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.705437183380127
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lucia_Kenny_Anthony
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lucia_Kenny_Anthony Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.42182016372680664
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lucia_Kenny_Anthony Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.4167604446411133
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lucia_Kenny_Anthony Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.39816713333129883
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Luc_Montagnier
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Luc_Montagnier Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.41265439987182617
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Luc_Montagnier Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.26549482345581055
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lubomir_Zaoralek
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lubomir_Zaoralek Recognized after 10 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.2574000358581543
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Lubomir_Zaoralek Recognized after 10 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 0.38695526123046875
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Louisa_Baileche
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Louisa_Baileche Recognized after 10 with accuracy: 0.7
# Not detected: 0.3 . Wrong recognition: 0.0
# Time: 0.26643824577331543
# [INFO] Recognizing faces...
# [INFO] elements: 10
# Louisa_Baileche Recognized after 10 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.42889928817749023
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Lucy_Liu
# [INFO] Recognizing faces...
# [INFO] elements: 75
# Lucy_Liu Recognized after 38 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3710618019104004
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Luis_Fonsi
# [INFO] Recognizing faces...
# [INFO] elements: 153
# Luis_Fonsi Recognized after 77 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.3183395862579346
# [INFO] Recognizing faces...
# [INFO] elements: 227
# Luis_Fonsi Recognized after 114 with accuracy: 0.9912280701754386
# Not detected: 0.008771929824561403 . Wrong recognition: 0.0
# Time: 3.1913397312164307
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Luis_Ernesto_Derbez_Bautista
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Luis_Ernesto_Derbez_Bautista Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4552102088928223
# [INFO] Recognizing faces...
# [INFO] elements: 123
# Luis_Ernesto_Derbez_Bautista Recognized after 123 with accuracy: 0.0
# Not detected: 1.0 . Wrong recognition: 0.0
# Time: 4.435976505279541
# [INFO] Recognizing faces...
# [INFO] elements: 61
# Luis_Ernesto_Derbez_Bautista Recognized after 31 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3695485591888428
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Ludivine_Sagnier
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Ludivine_Sagnier Recognized after 25 with accuracy: 0.88
# Not detected: 0.12 . Wrong recognition: 0.0
# Time: 0.9492113590240479
# [INFO] Recognizing faces...
# [INFO] elements: 117
# Ludivine_Sagnier Recognized after 59 with accuracy: 0.8305084745762712
# Not detected: 0.1694915254237288 . Wrong recognition: 0.0
# Time: 1.6439077854156494
# [INFO] Recognizing faces...
# [INFO] elements: 238
# Ludivine_Sagnier Recognized after 238 with accuracy: 0.27310924369747897
# Not detected: 0.726890756302521 . Wrong recognition: 0.0
# Time: 8.550808668136597
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Keith_Tyson
# [INFO] Recognizing faces...
# [INFO] elements: 163
# Keith_Tyson Recognized after 82 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.540693759918213
# [INFO] Recognizing faces...
# [INFO] elements: 118
# Keith_Tyson Recognized after 60 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6941869258880615
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Roberto_Benigni
# [INFO] Recognizing faces...
# [INFO] elements: 87
# Roberto_Benigni Recognized after 44 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.3154926300048828
# [INFO] Recognizing faces...
# [INFO] elements: 117
# Roberto_Benigni Recognized after 59 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.6594970226287842
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Robert_Woody_Johnson
# [INFO] Recognizing faces...
# [INFO] elements: 389
# Robert_Woody_Johnson Recognized after 195 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 5.473299980163574
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Robert_Nardelli
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Robert_Nardelli Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 0.9368846416473389
# [INFO] Recognizing faces...
# [INFO] elements: 49
# Robert_Nardelli Recognized after 25 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.0940570831298828
# [INFO] Recognizing faces...
# [INFO] elements: 126
# Robert_Nardelli Recognized after 64 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.261319398880005
# [INFO] Recognizing faces...
# [INFO] elements: 117
# Robert_Nardelli Recognized after 59 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 3.7839202880859375
# [INFO] Recognizing faces...
# [INFO] elements: 145
# Robert_Nardelli Recognized after 73 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 2.5407557487487793
# gdrive/My Drive/Colab Notebooks/PRIM/frame_images_mattia/Robert_Schuller
# [INFO] Recognizing faces...
# [INFO] elements: 65
# Robert_Schuller Recognized after 33 with accuracy: 1.0
# Not detected: 0.0 . Wrong recognition: 0.0
# Time: 1.4524998664855957
# -------------------------
# TEST ENDED
# -------------------------
# Accuracy on videos tested: 0.8725490196078431
